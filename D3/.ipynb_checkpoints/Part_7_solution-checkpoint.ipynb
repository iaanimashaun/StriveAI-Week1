# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 11.1

# %% [markdown]
# Write a program that reads the contents of the file "`blakepoems.txt`", splits it into words (where everything that is not a letter is considered a word boundary), and case-insensitively builds a dictionary that stores for every word how often it occurs in the text. Then print all the words with their quantities in alphabetical order.

# %%
# Counting words in blakepoems.txt.
#fp = open( "blakepoems.txt")

# %% [markdown]
# ### Solution: Exercise 11.1

# %%
import re

def word_counter(filepath):
    
    '''
    word_counter(filepath):

    reads a file and returns a dictionary of 
    words as keys and 
    word counts as values
    sorted alphabetically
    
    arguments:
    text: a filepath  
    
    '''
    
    # intitiate an empty dictionary
    word_dict = {}
    
    # open file
    with open(filepath) as file:
        
        # read each line
        lines = file.readlines()
        
        # iterate through each line
        for line in lines:
            
            # find all word character from each line and assign to variable words
            words = re.findall(r"\w+", line)
            
            # iterate through and convert each word in words to lower case 
            for word in words:
                word = word.lower()
                
                # if word is already in the dictionary of words, add 1
                if word in word_dict:
                    word_dict[word] += 1
                    
                # otherwise, add word to dict and initialise to 1
                else:
                    word_dict[word] = 1

    # return sorted word dictionary alphabetically
    return dict(sorted(word_dict.items(), key=lambda item: item[0]))
            #print(words)

# %%
word_counter('./text-files/blakepoems.txt')
# Out:
# {'1780': 1,
#  '1789': 1,
#  'a': 128,
#  'about': 1,
#  'abroad': 1,
#  'abstract': 1,
#  'ache': 1,
#  'admired': 1,
#  'adona': 1,
#  'afar': 1,
#  'affright': 1,
#  'after': 2,
#  'again': 3,
#  'against': 1,
#  'age': 2,
#  'aged': 1,
#  'agree': 1,
#  'ah': 7,
#  'air': 6,
#  'airy': 1,
#  'alas': 1,
#  'albion': 1,
#  'ale': 1,
#  'alehouse': 1,
#  'all': 39,
#  'allay': 1,
#  'alone': 1,
#  'altar': 1,
#  'always': 1,
#  'am': 16,
#  'ambush': 1,
#  'among': 8,
#  'an': 21,
#  'ancient': 3,
#  'and': 348,
#  'angel': 9,
#  'angels': 2,
#  'angry': 2,
#  'annoy': 1,
#  'another': 8,
#  'answer': 2,
#  'answerd': 3,
#  'answered': 2,
#  'anvil': 1,
#  'anxious': 1,
#  'any': 3,
#  'appall': 1,
#  'appals': 1,
#  'apparel': 1,
#  'appear': 2,
#  'appeared': 1,
#  'appears': 1,
#  'appendix': 1,
#  'apple': 1,
#  'are': 25,
#  'arise': 9,
#  'arm': 2,
#  'armed': 4,
#  'arms': 1,
#  'arose': 1,
#  'around': 5,
#  'arrow': 1,
#  'arrows': 1,
#  'art': 6,
#  'artful': 1,
#  'as': 16,
#  'ask': 2,
#  'asleep': 2,
#  'aspire': 2,
#  'astonish': 1,
#  'at': 7,
#  'author': 1,
#  'away': 24,
#  'awoke': 1,
#  'babe': 2,
#  'babes': 2,
#  'back': 3,
#  'bags': 2,
#  'baits': 1,
#  'balmy': 1,
#  'ban': 1,
#  'band': 1,
#  'bands': 2,
#  'bandy': 1,
#  'bane': 1,
#  'bank': 1,
#  'bar': 1,
#  'bard': 2,
#  'bare': 2,
#  'barrel': 1,
#  'be': 25,
#  'beadles': 1,
#  'beams': 3,
#  'bear': 5,
#  'bearing': 1,
#  'bears': 1,
#  'beast': 1,
#  'beasts': 2,
#  'beat': 1,
#  'beauty': 5,
#  'became': 2,
#  'because': 5,
#  'become': 1,
#  'becomes': 2,
#  'bed': 8,
#  'been': 2,
#  'beetle': 2,
#  'befall': 2,
#  'before': 7,
#  'began': 3,
#  'begone': 1,
#  'beguile': 2,
#  'beguiled': 2,
#  'beguiles': 1,
#  'beheld': 1,
#  'behind': 1,
#  'behold': 1,
#  'bells': 2,
#  'beneath': 2,
#  'benighted': 1,
#  'bereaved': 1,
#  'beside': 4,
#  'besides': 2,
#  'best': 1,
#  'betray': 1,
#  'bid': 1,
#  'bind': 2,
#  'binding': 1,
#  'binds': 1,
#  'birch': 1,
#  'bird': 4,
#  'birds': 11,
#  'birth': 1,
#  'black': 8,
#  'blackening': 1,
#  'bladder': 1,
#  'blade': 1,
#  'blake': 4,
#  'blasts': 2,
#  'bleak': 1,
#  'bleating': 1,
#  'bless': 3,
#  'blessing': 2,
#  'blights': 1,
#  'blind': 1,
#  'blood': 1,
#  'blossom': 4,
#  'blossoms': 3,
#  'blown': 3,
#  'blue': 1,
#  'blushed': 1,
#  'bodies': 1,
#  'bondage': 1,
#  'bones': 2,
#  'book': 6,
#  'bore': 7,
#  'born': 6,
#  'bosom': 4,
#  'both': 6,
#  'bound': 3,
#  'bow': 1,
#  'bowd': 2,
#  'bowed': 1,
#  'bower': 2,
#  'bowl': 1,
#  'boy': 11,
#  'boys': 2,
#  'brain': 2,
#  'break': 2,
#  'breast': 5,
#  'breath': 2,
#  'breathed': 1,
#  'breathing': 2,
#  'briars': 1,
#  'bright': 15,
#  'brings': 1,
#  'broke': 1,
#  'brook': 1,
#  'brooks': 1,
#  'brothers': 2,
#  'brought': 1,
#  'brows': 1,
#  'bruis': 1,
#  'brush': 1,
#  'brushed': 1,
#  'brushes': 1,
#  'bud': 1,
#  'buds': 2,
#  'builds': 2,
#  'built': 1,
#  'burned': 2,
#  'burning': 3,
#  'burnt': 1,
#  'bush': 1,
#  'but': 38,
#  'butterfly': 1,
#  'by': 24,
#  'cage': 1,
#  'call': 5,
#  'called': 2,
#  'calling': 1,
#  'calls': 2,
#  'came': 9,
#  'can': 29,
#  'cannot': 6,
#  'canst': 2,
#  'care': 12,
#  'caterpillar': 1,
#  'cattle': 1,
#  'caverns': 1,
#  'caves': 2,
#  'ceasd': 1,
#  'ceasing': 1,
#  'chain': 3,
#  'chained': 1,
#  'changed': 1,
#  'chapel': 2,
#  'charge': 2,
#  'chartered': 2,
#  'chase': 1,
#  'chaste': 1,
#  'cheer': 2,
#  'cheerful': 1,
#  'cherish': 3,
#  'cherries': 1,
#  'child': 18,
#  'children': 12,
#  'chimney': 3,
#  'chimneys': 1,
#  'chorus': 1,
#  'church': 6,
#  'clasp': 1,
#  'clay': 4,
#  'clean': 1,
#  'clear': 1,
#  'clime': 3,
#  'clod': 3,
#  'close': 2,
#  'closed': 1,
#  'clothed': 2,
#  'clothes': 1,
#  'clothing': 2,
#  'cloud': 15,
#  'clouds': 3,
#  'coat': 1,
#  'cock': 1,
#  'coffins': 2,
#  'coined': 1,
#  'cold': 7,
#  'come': 11,
#  'comfort': 1,
#  'companies': 1,
#  'company': 1,
#  'compelled': 1,
#  'complain': 2,
#  'complaind': 1,
#  'complainest': 1,
#  'consumed': 1,
#  'contagious': 1,
#  'control': 1,
#  'conveyed': 1,
#  'couches': 1,
#  'couching': 1,
#  'could': 6,
#  'countest': 1,
#  'court': 1,
#  'covered': 3,
#  'cow': 1,
#  'cradle': 2,
#  'crave': 1,
#  'creation': 1,
#  'creations': 1,
#  'cried': 1,
#  'cries': 1,
#  'crime': 1,
#  'crimson': 1,
#  'crops': 1,
#  'crow': 1,
#  'crown': 3,
#  'cruel': 2,
#  'cruelty': 3,
#  'crumbs': 1,
#  'cry': 7,
#  'crying': 1,
#  'curb': 1,
#  'curled': 1,
#  'curse': 1,
#  'curtain': 1,
#  'curtains': 1,
#  'd': 22,
#  'dacre': 1,
#  'dale': 3,
#  'dame': 1,
#  'dance': 2,
#  'dangerous': 1,
#  'dank': 1,
#  'dare': 4,
#  'dark': 7,
#  'darkening': 1,
#  'darkness': 2,
#  'daughter': 1,
#  'daughters': 1,
#  'day': 19,
#  'days': 4,
#  'dead': 2,
#  'deadly': 1,
#  'dear': 3,
#  'death': 6,
#  'deceit': 1,
#  'deceitful': 1,
#  'deceiving': 1,
#  'deep': 9,
#  'deeps': 1,
#  'delight': 14,
#  'delights': 1,
#  'dell': 1,
#  'den': 1,
#  'descend': 2,
#  'descended': 1,
#  'descending': 2,
#  'desert': 5,
#  'deserts': 1,
#  'desire': 2,
#  'desires': 1,
#  'despair': 2,
#  'despite': 1,
#  'destroy': 3,
#  'destruction': 1,
#  'devil': 1,
#  'dew': 4,
#  'dews': 2,
#  'dewy': 3,
#  'dick': 1,
#  'did': 12,
#  'didst': 3,
#  'die': 1,
#  'died': 2,
#  'dimpling': 1,
#  'disguise': 1,
#  'dismal': 2,
#  'dismay': 2,
#  'disputes': 1,
#  'distant': 2,
#  'distress': 2,
#  'divine': 6,
#  'do': 9,
#  'does': 18,
#  'dolors': 1,
#  'dome': 1,
#  'done': 3,
#  'door': 3,
#  'dost': 5,
#  'doth': 7,
#  'doubt': 1,
#  'dovelike': 2,
#  'doves': 1,
#  'down': 20,
#  'draw': 1,
#  'drawn': 1,
#  'dread': 5,
#  'dreadful': 1,
#  'dream': 4,
#  'dreams': 3,
#  'dreamt': 1,
#  'drear': 1,
#  'dreary': 1,
#  'dress': 4,
#  'dried': 1,
#  'drink': 4,
#  'drive': 2,
#  'driven': 2,
#  'drives': 1,
#  'droop': 1,
#  'drooping': 1,
#  'drop': 1,
#  'dropped': 1,
#  'duty': 1,
#  'dwell': 3,
#  'dwelling': 1,
#  'each': 5,
#  'eagle': 1,
#  'ear': 2,
#  'ears': 2,
#  'earth': 10,
#  'ease': 2,
#  'east': 1,
#  'eat': 1,
#  'echoed': 1,
#  'echoing': 3,
#  'else': 2,
#  'emerg': 1,
#  'emily': 1,
#  'emmet': 1,
#  'en': 1,
#  'end': 2,
#  'endless': 1,
#  'english': 2,
#  'engraved': 1,
#  'enter': 4,
#  'er': 16,
#  'eternal': 4,
#  'evening': 5,
#  'ever': 4,
#  'every': 17,
#  'everything': 1,
#  'evil': 1,
#  'ewes': 1,
#  'exhald': 1,
#  'experience': 3,
#  'eye': 5,
#  'eyed': 1,
#  'eyelids': 1,
#  'eyes': 9,
#  'face': 12,
#  'faces': 1,
#  'fade': 5,
#  'fades': 3,
#  'faint': 1,
#  'fair': 1,
#  'fall': 2,
#  'fallen': 3,
#  'falling': 1,
#  'falls': 1,
#  'false': 1,
#  'famished': 1,
#  'fancied': 1,
#  'farewell': 1,
#  'fast': 1,
#  'fasting': 1,
#  'father': 22,
#  'fear': 11,
#  'fearest': 1,
#  'fearful': 2,
#  'fears': 5,
#  'fed': 2,
#  'feed': 4,
#  'feel': 3,
#  'feet': 5,
#  'fen': 1,
#  'fibrous': 1,
#  'fields': 2,
#  'fiend': 2,
#  'fierce': 1,
#  'fiery': 1,
#  'fighting': 1,
#  'filled': 6,
#  'find': 4,
#  'fire': 4,
#  'fix': 1,
#  'flame': 1,
#  'fled': 6,
#  'flesh': 1,
#  'flew': 2,
#  'flies': 1,
#  'flocks': 2,
#  'floor': 1,
#  'flourish': 1,
#  'flow': 3,
#  'flowed': 1,
#  'flower': 5,
#  'flowers': 9,
#  'flute': 1,
#  'fly': 7,
#  'foe': 3,
#  'fold': 2,
#  'folk': 1,
#  'follow': 3,
#  'followed': 1,
#  'folly': 1,
#  'fondness': 1,
#  'food': 4,
#  'foot': 2,
#  'for': 32,
#  'forest': 1,
#  'forests': 1,
#  'forge': 1,
#  'forged': 2,
#  'forget': 1,
#  'forgot': 1,
#  'forlorn': 1,
#  'form': 8,
#  'former': 1,
#  'forth': 2,
#  'found': 3,
#  'fountains': 1,
#  'frame': 2,
#  'free': 6,
#  'freeze': 1,
#  'fresh': 1,
#  'friend': 1,
#  'from': 32,
#  'frowning': 2,
#  'fruit': 1,
#  'fruitful': 1,
#  'fruits': 2,
#  'full': 1,
#  'furnace': 2,
#  'further': 1,
#  'future': 2,
#  'futurity': 1,
#  'gambolled': 1,
#  'garden': 7,
#  'garments': 1,
#  'gates': 2,
#  'gather': 1,
#  'gave': 3,
#  'generation': 1,
#  'gentle': 5,
#  'gently': 1,
#  'gifts': 1,
#  'gilded': 1,
#  'girl': 4,
#  'girls': 2,
#  'give': 3,
#  'given': 3,
#  'gives': 4,
#  'giving': 1,
#  'glad': 1,
#  'glass': 1,
#  'glee': 1,
#  'glistening': 1,
#  'glittering': 1,
#  'glitters': 1,
#  'glow': 1,
#  'go': 8,
#  'god': 11,
#  'gods': 1,
#  'goes': 1,
#  'going': 1,
#  'gold': 6,
#  'golden': 8,
#  'gone': 6,
#  'good': 1,
#  'gorge': 1,
#  'got': 1,
#  'gowns': 1,
#  'graces': 1,
#  'grasp': 1,
#  'grass': 7,
#  'grasshopper': 1,
#  'grave': 3,
#  'graves': 2,
#  'graze': 1,
#  'great': 2,
#  'greater': 1,
#  'green': 16,
#  'grew': 1,
#  'grey': 3,
#  'grief': 4,
#  'griefs': 1,
#  'groan': 1,
#  'groaned': 1,
#  'ground': 5,
#  'grove': 3,
#  'grow': 2,
#  'growl': 1,
#  'grows': 1,
#  'guard': 1,
#  'guarded': 2,
#  'guardians': 1,
#  'ha': 4,
#  'had': 7,
#  'hair': 6,
#  'hairs': 1,
#  'hallowed': 1,
#  'hammer': 1,
#  'hand': 9,
#  'hands': 3,
#  'hapless': 1,
#  'happy': 19,
#  'har': 4,
#  'harlot': 1,
#  'harm': 2,
#  'harmonious': 1,
#  'has': 5,
#  'hath': 1,
#  'have': 17,
#  'he': 56,
#  'head': 14,
#  'headed': 1,
#  'health': 1,
#  'healthy': 1,
#  'hear': 16,
#  'heard': 12,
#  'hearing': 1,
#  'hears': 4,
#  'hearse': 1,
#  'heart': 11,
#  'heat': 5,
#  'heath': 2,
#  'heathen': 1,
#  'heaven': 10,
#  'heavenly': 1,
#  'heavy': 2,
#  'heedful': 1,
#  'hell': 2,
#  'helpless': 4,
#  'her': 34,
#  'here': 2,
#  'hid': 2,
#  'hide': 1,
#  'hie': 1,
#  'high': 3,
#  'hill': 2,
#  'hills': 2,
#  'him': 11,
#  'himself': 1,
#  'his': 57,
#  'hither': 1,
#  'hoar': 1,
#  'hoarse': 1,
#  'hoary': 1,
#  'hollow': 3,
#  'holy': 13,
#  'home': 4,
#  'honey': 2,
#  'horn': 2,
#  'horses': 1,
#  'hour': 2,
#  'house': 1,
#  'hover': 3,
#  'hovering': 1,
#  'how': 14,
#  'howl': 2,
#  'howling': 1,
#  'hum': 2,
#  'human': 16,
#  'humble': 4,
#  'humid': 1,
#  'humility': 1,
#  'hunger': 1,
#  'hungry': 1,
#  'huntsman': 1,
#  'hush': 1,
#  'i': 130,
#  'if': 17,
#  'ii': 1,
#  'iii': 1,
#  'image': 8,
#  'immortal': 3,
#  'impress': 1,
#  'in': 141,
#  'included': 1,
#  'increase': 1,
#  'indeed': 1,
#  'indignant': 1,
#  'infant': 16,
#  'infants': 3,
#  'infixes': 1,
#  'inhaling': 1,
#  'inherit': 1,
#  'injury': 1,
#  'innocence': 3,
#  'innocent': 4,
#  'into': 5,
#  'introduction': 2,
#  'invisible': 1,
#  'iron': 2,
#  'is': 52,
#  'it': 29,
#  'its': 14,
#  'itself': 7,
#  'iv': 1,
#  'jack': 1,
#  'jealous': 1,
#  'jealousy': 3,
#  'jesus': 1,
#  'jew': 1,
#  'joe': 1,
#  'john': 1,
#  'join': 1,
#  'journey': 1,
#  'joy': 25,
#  'joys': 3,
#  'judge': 1,
#  'just': 1,
#  'keep': 3,
#  'key': 1,
#  'kind': 1,
#  'kindled': 1,
#  'king': 1,
#  'kingly': 1,
#  'kiss': 2,
#  'kissed': 3,
#  'kisses': 2,
#  'knee': 1,
#  'kneels': 1,
#  'knew': 4,
#  'knits': 1,
#  'know': 11,
#  'laid': 1,
#  'lamb': 15,
#  'lambs': 5,
#  'lamentation': 1,
#  'lamentations': 1,
#  'land': 5,
#  'lap': 1,
#  'laps': 1,
#  'lapsed': 1,
#  'lark': 1,
#  'laugh': 6,
#  'laughed': 1,
#  'laughing': 5,
#  'laughs': 2,
#  'lay': 10,
#  'lead': 1,
#  'leaf': 2,
#  'lean': 1,
#  'leaped': 1,
#  'leaping': 1,
#  'leapt': 1,
#  'learn': 2,
#  'learning': 1,
#  'leave': 2,
#  'leaves': 2,
#  'led': 6,
#  'left': 1,
#  'leopards': 1,
#  'lest': 1,
#  'let': 7,
#  'lick': 2,
#  'licks': 1,
#  'lie': 2,
#  'lies': 1,
#  'life': 8,
#  'lifted': 1,
#  'light': 11,
#  'like': 35,
#  'lilly': 1,
#  'lillys': 2,
#  'lily': 5,
#  'limbs': 1,
#  'link': 1,
#  'lion': 5,
#  'lioness': 1,
#  'listning': 2,
#  'little': 45,
#  'liv': 1,
#  'live': 6,
#  'livelong': 2,
#  'lively': 1,
#  'lives': 2,
#  'll': 4,
#  'lo': 1,
#  'locked': 1,
#  'locks': 1,
#  'london': 2,
#  'lonely': 3,
#  'long': 1,
#  'look': 5,
#  'lookst': 1,
#  'loosed': 1,
#  'loss': 1,
#  'lost': 8,
#  'lot': 2,
#  'lotus': 1,
#  'loud': 1,
#  'louder': 1,
#  'love': 29,
#  'loved': 1,
#  'lovely': 4,
#  'loves': 3,
#  'loving': 1,
#  'lowly': 3,
#  'lurch': 1,
#  'luvah': 1,
#  'lyca': 9,
#  'made': 6,
#  'maid': 7,
#  'maiden': 4,
#  'make': 5,
#  'maker': 4,
#  'making': 2,
#  'man': 6,
#  'manacles': 1,
#  'mane': 3,
#  'manna': 1,
#  'many': 7,
#  'mark': 1,
#  'marks': 2,
#  'marriage': 1,
#  'mary': 1,
#  'mass': 1,
#  'matron': 1,
#  'may': 6,
#  'maze': 1,
#  'me': 34,
#  'mead': 1,
#  'meadows': 1,
#  'mean': 1,
#  'meanest': 1,
#  'meek': 2,
#  'meekin': 1,
#  'meekness': 1,
#  'meet': 3,
#  'mellowing': 1,
#  'melts': 1,
#  'men': 4,
#  'mercy': 8,
#  'merrily': 7,
#  'merry': 9,
#  'met': 1,
#  'methought': 1,
#  'metres': 1,
#  'midnight': 1,
#  'midst': 1,
#  'might': 2,
#  'mighty': 1,
#  'mild': 7,
#  'milk': 1,
#  'milked': 1,
#  'milky': 2,
#  'mind': 5,
#  'mine': 2,
#  'mire': 1,
#  'misery': 2,
#  'mistress': 1,
#  'mne': 1,
#  'moan': 3,
#  'moans': 3,
#  'modest': 4,
#  'mole': 1,
#  'moon': 2,
#  'moony': 1,
#  'more': 9,
#  'morn': 8,
#  'morning': 10,
#  'mortal': 4,
#  'most': 3,
#  'mother': 19,
#  'mothers': 2,
#  'motto': 1,
#  'mould': 1,
#  'mouth': 1,
#  'mouths': 1,
#  'move': 1,
#  'multitude': 1,
#  'multitudes': 2,
#  'music': 1,
#  'must': 3,
#  'mute': 1,
#  'mutual': 1,
#  'my': 83,
#  'mystery': 3,
#  'naked': 5,
#  'name': 5,
#  'narrow': 1,
#  'nature': 1,
#  'ne': 1,
#  'near': 6,
#  'neck': 2,
#  'ned': 1,
#  'need': 1,
#  'nest': 4,
#  'never': 17,
#  'new': 4,
#  'next': 1,
#  'nibbled': 1,
#  'nigh': 2,
#  'night': 28,
#  'nightingale': 1,
#  'nights': 1,
#  'ning': 1,
#  'nipped': 1,
#  'no': 18,
#  'noise': 2,
#  'none': 3,
#  'noonday': 1,
#  'nor': 15,
#  'northern': 1,
#  'nostril': 1,
#  'nostrils': 1,
#  'not': 37,
#  'note': 1,
#  'notes': 2,
#  'nothing': 2,
#  'nought': 1,
#  'nourish': 1,
#  'now': 7,
#  'numerous': 1,
#  'nuptial': 1,
#  'nurse': 2,
#  'nuts': 1,
#  'o': 26,
#  'oak': 1,
#  'of': 146,
#  'off': 1,
#  'offered': 1,
#  'oft': 1,
#  'oh': 11,
#  'oil': 2,
#  'old': 6,
#  'on': 44,
#  'ona': 1,
#  'once': 4,
#  'one': 4,
#  'ones': 3,
#  'only': 3,
#  'opened': 1,
#  'opening': 1,
#  'or': 21,
#  'others': 1,
#  'our': 22,
#  'ourselves': 1,
#  'out': 5,
#  'outstretched': 1,
#  'outworn': 1,
#  'over': 8,
#  'own': 4,
#  'page': 1,
#  'painted': 1,
#  'pair': 1,
#  'palace': 2,
#  'pale': 5,
#  'paleness': 1,
#  'parents': 4,
#  'parson': 1,
#  'parsons': 1,
#  'part': 2,
#  'parting': 1,
#  'partner': 1,
#  'pass': 2,
#  'passed': 1,
#  'past': 1,
#  'pathless': 1,
#  'paul': 1,
#  'peace': 9,
#  'peaceful': 1,
#  'pearly': 1,
#  'pebble': 2,
#  'pen': 1,
#  'pensive': 1,
#  'perches': 1,
#  'perfume': 1,
#  'perplex': 1,
#  'picks': 1,
#  'pined': 1,
#  'pipe': 4,
#  'piped': 2,
#  'piper': 2,
#  'piping': 3,
#  'pit': 2,
#  'piteous': 1,
#  'pity': 9,
#  'pitying': 5,
#  'place': 2,
#  'plagues': 1,
#  'plain': 1,
#  'plants': 1,
#  'play': 9,
#  'pleasant': 5,
#  'please': 2,
#  'plot': 1,
#  'plough': 1,
#  'plowman': 1,
#  'pluck': 1,
#  'poems': 1,
#  'pointed': 1,
#  'poison': 2,
#  'pole': 2,
#  'ponder': 2,
#  'poor': 4,
#  'porter': 1,
#  'possible': 1,
#  'pour': 2,
#  'pouring': 1,
#  'pours': 1,
#  'poverty': 2,
#  'praise': 2,
#  'pray': 3,
#  'prays': 2,
#  'preach': 1,
#  'present': 1,
#  'presse': 1,
#  'pretty': 8,
#  'prey': 3,
#  'pride': 1,
#  'priest': 2,
#  'priestly': 1,
#  'priests': 1,
#  'prime': 1,
#  'printer': 1,
#  'prisoned': 1,
#  'prophetic': 1,
#  'pull': 1,
#  'punish': 1,
#  'purify': 1,
#  'put': 2,
#  'puts': 1,
#  'quarrel': 1,
#  'queen': 5,
#  'quiet': 1,
#  'radiance': 1,
#  'rain': 1,
#  'rais': 1,
#  'raise': 1,
#  'raised': 1,
#  'raising': 1,
#  'raptures': 1,
#  'raven': 1,
#  ...}

# %% [markdown]
# ### Exercise 11.2

# %% [markdown]
# Do the same thing as you did for the previous exercise, but now process the text line by line. This is something that you would have to do if you had to process a very long text (as it is the case).

# %% [markdown]
# ### Solution: Exercise 11.2

# %%
from collections import Counter
import re

def word_counter_by_line(filepath):
    
    '''
    word_counter_by_line(filepath):

    reads a file and returns a dictionary of 
    words as keys and 
    word counts as values
    sorted alphabetically
    
    arguments:
    text: a filepath  
    
    '''
    
    # intitiate an empty dictionary
    word_dict_by_line = {}
    
    # open file
    with open(filepath) as file:
        
        # read each line
        lines = file.readlines()
        
        # iterate through each line
        for line in lines:
            
            # check if line is not whitespace....
            if line != '\n':
                
            # ....find all word character from each non-whitespace line and assign to variable words
                words = re.findall(r"\w+", line)

                # get the words and word counts for each line 
                words_by_line = Counter(words).keys()
                word_count_by_line = Counter(words).values()
                
                # add words and counts of every line to dictionary 
                word_dict_by_line[f'line {lines.index(line)+1}'] = dict(zip(words_by_line,word_count_by_line))

    # return sorted word dictionary alphabetically
    return word_dict_by_line

# %%
word_counter_by_line('./text-files/blakepoems.txt')
# Out:
# {'line 1': {'Poems': 1, 'by': 1, 'William': 1, 'Blake': 1, '1789': 1},
#  'line 3': {'You': 1, 'can': 1, 'do': 1, 'this': 1},
#  'line 6': {'SONGS': 1, 'OF': 2, 'INNOCENCE': 1, 'AND': 1, 'EXPERIENCE': 1},
#  'line 7': {'and': 1, 'THE': 1, 'BOOK': 1, 'of': 1, 'THEL': 1},
#  'line 10': {'SONGS': 1, 'OF': 1, 'INNOCENCE': 1},
#  'line 13': {'INTRODUCTION': 1},
#  'line 15': {'Piping': 1, 'down': 1, 'the': 1, 'valleys': 1, 'wild': 1},
#  'line 16': {'Piping': 1, 'songs': 1, 'of': 1, 'pleasant': 1, 'glee': 1},
#  'line 17': {'On': 1, 'a': 2, 'cloud': 1, 'I': 1, 'saw': 1, 'child': 1},
#  'line 18': {'And': 1, 'he': 1, 'laughing': 1, 'said': 1, 'to': 1, 'me': 1},
#  'line 20': {'Pipe': 1, 'a': 2, 'song': 1, 'about': 1, 'Lamb': 1},
#  'line 21': {'So': 1, 'I': 1, 'piped': 1, 'with': 1, 'merry': 1, 'cheer': 1},
#  'line 22': {'Piper': 1, 'pipe': 1, 'that': 1, 'song': 1, 'again': 1},
#  'line 23': {'So': 1,
#   'I': 1,
#   'piped': 1,
#   'he': 1,
#   'wept': 1,
#   'to': 1,
#   'hear': 1},
#  'line 25': {'Drop': 1, 'thy': 2, 'pipe': 2, 'happy': 1},
#  'line 26': {'Sing': 1, 'thy': 1, 'songs': 1, 'of': 1, 'happy': 1, 'cheer': 1},
#  'line 27': {'So': 1, 'I': 1, 'sang': 1, 'the': 1, 'same': 1, 'again': 1},
#  'line 28': {'While': 1,
#   'he': 1,
#   'wept': 1,
#   'with': 1,
#   'joy': 1,
#   'to': 1,
#   'hear': 1},
#  'line 30': {'Piper': 1, 'sit': 1, 'thee': 1, 'down': 1, 'and': 1, 'write': 1},
#  'line 31': {'In': 1,
#   'a': 1,
#   'book': 1,
#   'that': 1,
#   'all': 1,
#   'may': 1,
#   'read': 1},
#  'line 32': {'So': 1,
#   'he': 1,
#   'vanish': 1,
#   'd': 1,
#   'from': 1,
#   'my': 1,
#   'sight': 1},
#  'line 33': {'And': 1,
#   'I': 1,
#   'pluck': 1,
#   'd': 1,
#   'a': 1,
#   'hollow': 1,
#   'reed': 1},
#  'line 35': {'And': 1, 'I': 1, 'made': 1, 'a': 1, 'rural': 1, 'pen': 1},
#  'line 36': {'And': 1,
#   'I': 1,
#   'stain': 1,
#   'd': 1,
#   'the': 1,
#   'water': 1,
#   'clear': 1},
#  'line 37': {'And': 1, 'I': 1, 'wrote': 1, 'my': 1, 'happy': 1, 'songs': 1},
#  'line 38': {'Every': 1, 'child': 1, 'may': 1, 'joy': 1, 'to': 1, 'hear': 1},
#  'line 41': {'THE': 1, 'SHEPHERD': 1},
#  'line 43': {'How': 1,
#   'sweet': 2,
#   'is': 1,
#   'the': 1,
#   'Shepherd': 1,
#   's': 1,
#   'lot': 1},
#  'line 44': {'From': 1,
#   'the': 2,
#   'morn': 1,
#   'to': 1,
#   'evening': 1,
#   'he': 1,
#   'stays': 1},
#  'line 45': {'He': 1,
#   'shall': 1,
#   'follow': 1,
#   'his': 1,
#   'sheep': 1,
#   'all': 1,
#   'the': 1,
#   'day': 1},
#  'line 46': {'And': 1,
#   'his': 1,
#   'tongue': 1,
#   'shall': 1,
#   'be': 1,
#   'filled': 1,
#   'with': 1,
#   'praise': 1},
#  'line 48': {'For': 1,
#   'he': 1,
#   'hears': 1,
#   'the': 1,
#   'lambs': 1,
#   'innocent': 1,
#   'call': 1},
#  'line 49': {'And': 1,
#   'he': 1,
#   'hears': 1,
#   'the': 1,
#   'ewes': 1,
#   'tender': 1,
#   'reply': 1},
#  'line 50': {'He': 1,
#   'is': 1,
#   'watching': 1,
#   'while': 1,
#   'they': 1,
#   'are': 1,
#   'in': 1,
#   'peace': 1},
#  'line 51': {'For': 1,
#   'they': 1,
#   'know': 1,
#   'when': 1,
#   'their': 1,
#   'Shepherd': 1,
#   'is': 1,
#   'nigh': 1},
#  'line 54': {'THE': 1, 'ECHOING': 1, 'GREEN': 1},
#  'line 56': {'The': 1, 'sun': 1, 'does': 1, 'arise': 1},
#  'line 57': {'And': 1, 'make': 1, 'happy': 1, 'the': 1, 'skies': 1},
#  'line 58': {'The': 1, 'merry': 1, 'bells': 1, 'ring': 1},
#  'line 59': {'To': 1, 'welcome': 1, 'the': 1, 'Spring': 1},
#  'line 60': {'The': 1, 'skylark': 1, 'and': 1, 'thrush': 1},
#  'line 61': {'The': 1, 'birds': 1, 'of': 1, 'the': 1, 'bush': 1},
#  'line 62': {'Sing': 1, 'louder': 1, 'around': 1},
#  'line 63': {'To': 1, 'the': 1, 'bells': 1, 'cheerful': 1, 'sound': 1},
#  'line 64': {'While': 1,
#   'our': 1,
#   'sports': 1,
#   'shall': 1,
#   'be': 1,
#   'seen': 1},
#  'line 65': {'On': 1, 'the': 1, 'echoing': 1, 'Green': 1},
#  'line 67': {'Old': 1, 'John': 1, 'with': 1, 'white': 1, 'hair': 1},
#  'line 68': {'Does': 1, 'laugh': 1, 'away': 1, 'care': 1},
#  'line 69': {'Sitting': 1, 'under': 1, 'the': 1, 'oak': 1},
#  'line 70': {'Among': 1, 'the': 1, 'old': 1, 'folk': 1},
#  'line 71': {'They': 1, 'laugh': 1, 'at': 1, 'our': 1, 'play': 1},
#  'line 72': {'And': 1, 'soon': 1, 'they': 1, 'all': 1, 'say': 1},
#  'line 73': {'Such': 1, 'such': 1, 'were': 1, 'the': 1, 'joys': 1},
#  'line 74': {'When': 1, 'we': 1, 'all': 1, 'girls': 1, 'and': 1, 'boys': 1},
#  'line 75': {'In': 1, 'our': 1, 'youth': 1, 'time': 1, 'were': 1, 'seen': 1},
#  'line 76': {'On': 1, 'the': 1, 'echoing': 1, 'Green': 1},
#  'line 78': {'Till': 1, 'the': 1, 'little': 1, 'ones': 1, 'weary': 1},
#  'line 79': {'No': 1, 'more': 1, 'can': 1, 'be': 1, 'merry': 1},
#  'line 80': {'The': 1, 'sun': 1, 'does': 1, 'descend': 1},
#  'line 81': {'And': 1, 'our': 1, 'sports': 1, 'have': 1, 'an': 1, 'end': 1},
#  'line 82': {'Round': 1,
#   'the': 1,
#   'laps': 1,
#   'of': 1,
#   'their': 1,
#   'mothers': 1},
#  'line 83': {'Many': 1, 'sisters': 1, 'and': 1, 'brothers': 1},
#  'line 84': {'Like': 1, 'birds': 1, 'in': 1, 'their': 1, 'nest': 1},
#  'line 85': {'Are': 1, 'ready': 1, 'for': 1, 'rest': 1},
#  'line 86': {'And': 1, 'sport': 1, 'no': 1, 'more': 1, 'seen': 1},
#  'line 87': {'On': 1, 'the': 1, 'darkening': 1, 'green': 1},
#  'line 90': {'THE': 1, 'LAMB': 1},
#  'line 92': {'Little': 1, 'Lamb': 1, 'who': 1, 'make': 1, 'thee': 1},
#  'line 93': {'Dost': 1, 'thou': 1, 'know': 1, 'who': 1, 'made': 1, 'thee': 1},
#  'line 94': {'Gave': 1, 'thee': 2, 'life': 1, 'and': 1, 'bid': 1, 'feed': 1},
#  'line 95': {'By': 1,
#   'the': 2,
#   'stream': 1,
#   'and': 1,
#   'o': 1,
#   'er': 1,
#   'mead': 1},
#  'line 96': {'Gave': 1, 'thee': 1, 'clothing': 1, 'of': 1, 'delight': 1},
#  'line 97': {'Softest': 1, 'clothing': 1, 'wolly': 1, 'bright': 1},
#  'line 98': {'Gave': 1, 'thee': 1, 'such': 1, 'a': 1, 'tender': 1, 'voice': 1},
#  'line 99': {'Making': 1, 'all': 1, 'the': 1, 'vales': 1, 'rejoice': 1},
#  'line 100': {'Little': 1, 'Lamb': 1, 'who': 1, 'made': 1, 'thee': 1},
#  'line 101': {'Dost': 1, 'thou': 1, 'know': 1, 'who': 1, 'made': 1, 'thee': 1},
#  'line 103': {'Little': 1, 'Lamb': 1, 'I': 1, 'll': 1, 'tell': 1, 'thee': 1},
#  'line 104': {'Little': 1, 'Lamb': 1, 'I': 1, 'll': 1, 'tell': 1, 'thee': 1},
#  'line 105': {'He': 1, 'is': 1, 'called': 1, 'by': 1, 'thy': 1, 'name': 1},
#  'line 106': {'For': 1, 'He': 1, 'calls': 1, 'Himself': 1, 'a': 1, 'Lamb': 1},
#  'line 107': {'He': 2, 'is': 2, 'meek': 1, 'and': 1, 'mild': 1},
#  'line 108': {'He': 1, 'became': 1, 'a': 1, 'little': 1, 'child': 1},
#  'line 109': {'I': 1, 'a': 2, 'child': 1, 'and': 1, 'thou': 1, 'lamb': 1},
#  'line 110': {'We': 1, 'are': 1, 'called': 1, 'by': 1, 'His': 1, 'name': 1},
#  'line 111': {'Little': 1, 'Lamb': 1, 'God': 1, 'bless': 1, 'thee': 1},
#  'line 115': {'THE': 1, 'LITTLE': 1, 'BLACK': 1, 'BOY': 1},
#  'line 117': {'My': 1,
#   'mother': 1,
#   'bore': 1,
#   'me': 1,
#   'in': 1,
#   'the': 1,
#   'southern': 1,
#   'wild': 1},
#  'line 118': {'And': 1,
#   'I': 1,
#   'am': 1,
#   'black': 1,
#   'but': 1,
#   'oh': 1,
#   'my': 1,
#   'soul': 1,
#   'is': 1,
#   'white': 1},
#  'line 119': {'White': 1,
#   'as': 1,
#   'an': 1,
#   'angel': 1,
#   'is': 1,
#   'the': 1,
#   'English': 1,
#   'child': 1},
#  'line 120': {'But': 1,
#   'I': 1,
#   'am': 1,
#   'black': 1,
#   'as': 1,
#   'if': 1,
#   'bereaved': 1,
#   'of': 1,
#   'light': 1},
#  'line 122': {'My': 1,
#   'mother': 1,
#   'taught': 1,
#   'me': 1,
#   'underneath': 1,
#   'a': 1,
#   'tree': 1},
#  'line 123': {'And': 1,
#   'sitting': 1,
#   'down': 1,
#   'before': 1,
#   'the': 1,
#   'heat': 1,
#   'of': 1,
#   'day': 1},
#  'line 124': {'She': 1,
#   'took': 1,
#   'me': 2,
#   'on': 1,
#   'her': 1,
#   'lap': 1,
#   'and': 1,
#   'kissed': 1},
#  'line 125': {'And': 1,
#   'pointed': 1,
#   'to': 2,
#   'the': 1,
#   'east': 1,
#   'began': 1,
#   'say': 1},
#  'line 127': {'Look': 1,
#   'on': 1,
#   'the': 1,
#   'rising': 1,
#   'sun': 1,
#   'there': 1,
#   'God': 1,
#   'does': 1,
#   'live': 1},
#  'line 128': {'And': 1,
#   'gives': 2,
#   'His': 2,
#   'light': 1,
#   'and': 1,
#   'heat': 1,
#   'away': 1},
#  'line 129': {'And': 1,
#   'flowers': 1,
#   'and': 3,
#   'trees': 1,
#   'beasts': 1,
#   'men': 1,
#   'receive': 1},
#  'line 130': {'Comfort': 1,
#   'in': 2,
#   'morning': 1,
#   'joy': 1,
#   'the': 1,
#   'noonday': 1},
#  'line 132': {'And': 1,
#   'we': 1,
#   'are': 1,
#   'put': 1,
#   'on': 1,
#   'earth': 1,
#   'a': 1,
#   'little': 1,
#   'space': 1},
#  'line 133': {'That': 1,
#   'we': 1,
#   'may': 1,
#   'learn': 1,
#   'to': 1,
#   'bear': 1,
#   'the': 1,
#   'beams': 1,
#   'of': 1,
#   'love': 1},
#  'line 134': {'And': 1,
#   'these': 1,
#   'black': 1,
#   'bodies': 1,
#   'and': 1,
#   'this': 1,
#   'sunburnt': 1,
#   'face': 1},
#  'line 135': {'Is': 1,
#   'but': 1,
#   'a': 2,
#   'cloud': 1,
#   'and': 1,
#   'like': 1,
#   'shady': 1,
#   'grove': 1},
#  'line 137': {'For': 1,
#   'when': 1,
#   'our': 1,
#   'souls': 1,
#   'have': 1,
#   'learn': 1,
#   'd': 1,
#   'the': 1,
#   'heat': 1,
#   'to': 1,
#   'bear': 1},
#  'line 138': {'The': 1,
#   'cloud': 1,
#   'will': 1,
#   'vanish': 1,
#   'we': 1,
#   'shall': 1,
#   'hear': 1,
#   'His': 1,
#   'voice': 1},
#  'line 139': {'Saying': 1,
#   'Come': 1,
#   'out': 1,
#   'from': 1,
#   'the': 1,
#   'grove': 1,
#   'my': 1,
#   'love': 1,
#   'and': 1,
#   'care': 1},
#  'line 140': {'And': 1,
#   'round': 1,
#   'my': 1,
#   'golden': 1,
#   'tent': 1,
#   'like': 1,
#   'lambs': 1,
#   'rejoice': 1},
#  'line 142': {'Thus': 1,
#   'did': 1,
#   'my': 1,
#   'mother': 1,
#   'say': 1,
#   'and': 1,
#   'kissed': 1,
#   'me': 1},
#  'line 143': {'And': 1,
#   'thus': 1,
#   'I': 1,
#   'say': 1,
#   'to': 1,
#   'little': 1,
#   'English': 1,
#   'boy': 1},
#  'line 144': {'When': 1,
#   'I': 1,
#   'from': 2,
#   'black': 1,
#   'and': 1,
#   'he': 1,
#   'white': 1,
#   'cloud': 1,
#   'free': 1},
#  'line 145': {'And': 1,
#   'round': 1,
#   'the': 1,
#   'tent': 1,
#   'of': 1,
#   'God': 1,
#   'like': 1,
#   'lambs': 1,
#   'we': 1,
#   'joy': 1},
#  'line 147': {'I': 1,
#   'll': 1,
#   'shade': 1,
#   'him': 1,
#   'from': 1,
#   'the': 1,
#   'heat': 1,
#   'till': 1,
#   'he': 1,
#   'can': 1,
#   'bear': 1},
#  'line 148': {'To': 1,
#   'lean': 1,
#   'in': 1,
#   'joy': 1,
#   'upon': 1,
#   'our': 1,
#   'Father': 1,
#   's': 1,
#   'knee': 1},
#  'line 149': {'And': 1,
#   'then': 1,
#   'I': 1,
#   'll': 1,
#   'stand': 1,
#   'and': 1,
#   'stroke': 1,
#   'his': 1,
#   'silver': 1,
#   'hair': 1},
#  'line 150': {'And': 1,
#   'be': 1,
#   'like': 1,
#   'him': 1,
#   'and': 1,
#   'he': 1,
#   'will': 1,
#   'then': 1,
#   'love': 1,
#   'me': 1},
#  'line 153': {'THE': 1, 'BLOSSOM': 1},
#  'line 155': {'Merry': 1, 'merry': 1, 'sparrow': 1},
#  'line 156': {'Under': 1, 'leaves': 1, 'so': 1, 'green': 1},
#  'line 157': {'A': 1, 'happy': 1, 'blossom': 1},
#  'line 158': {'Sees': 1, 'you': 1, 'swift': 1, 'as': 1, 'arrow': 1},
#  'line 159': {'Seek': 1, 'your': 1, 'cradle': 1, 'narrow': 1},
#  'line 160': {'Near': 1, 'my': 1, 'bosom': 1},
#  'line 161': {'Pretty': 1, 'pretty': 1, 'robin': 1},
#  'line 164': {'Hears': 1, 'you': 1, 'sobbing': 2},
#  'line 165': {'Pretty': 1, 'pretty': 1, 'robin': 1},
#  'line 169': {'THE': 1, 'CHIMNEY': 1, 'SWEEPER': 1},
#  'line 171': {'When': 1,
#   'my': 1,
#   'mother': 1,
#   'died': 1,
#   'I': 1,
#   'was': 1,
#   'very': 1,
#   'young': 1},
#  'line 172': {'And': 1,
#   'my': 2,
#   'father': 1,
#   'sold': 1,
#   'me': 1,
#   'while': 1,
#   'yet': 1,
#   'tongue': 1},
#  'line 173': {'Could': 1, 'scarcely': 1, 'cry': 1, 'Weep': 1, 'weep': 3},
#  'line 174': {'So': 1,
#   'your': 1,
#   'chimneys': 1,
#   'I': 2,
#   'sweep': 1,
#   'and': 1,
#   'in': 1,
#   'soot': 1,
#   'sleep': 1},
#  'line 176': {'There': 1,
#   's': 1,
#   'little': 1,
#   'Tom': 1,
#   'Dacre': 1,
#   'who': 1,
#   'cried': 1,
#   'when': 1,
#   'his': 1,
#   'head': 1},
#  'line 177': {'That': 1,
#   'curled': 1,
#   'like': 1,
#   'a': 1,
#   'lamb': 1,
#   's': 1,
#   'back': 1,
#   'was': 1,
#   'shaved': 1,
#   'so': 1,
#   'I': 1,
#   'said': 1},
#  'line 178': {'Hush': 1,
#   'Tom': 1,
#   'never': 1,
#   'mind': 1,
#   'it': 1,
#   'for': 1,
#   'when': 1,
#   'your': 1,
#   'head': 1,
#   's': 1,
#   'bare': 1},
#  'line 179': {'You': 1,
#   'know': 1,
#   'that': 1,
#   'the': 1,
#   'soot': 1,
#   'cannot': 1,
#   'spoil': 1,
#   'your': 1,
#   'white': 1,
#   'hair': 1},
#  'line 181': {'And': 1,
#   'so': 1,
#   'he': 1,
#   'was': 1,
#   'quiet': 1,
#   'and': 1,
#   'that': 1,
#   'very': 1,
#   'night': 1},
#  'line 182': {'As': 1,
#   'Tom': 1,
#   'was': 1,
#   'a': 2,
#   'sleeping': 1,
#   'he': 1,
#   'had': 1,
#   'such': 1,
#   'sight': 1},
#  'line 183': {'That': 1,
#   'thousands': 1,
#   'of': 1,
#   'sweepers': 1,
#   'Dick': 1,
#   'Joe': 1,
#   'Ned': 1,
#   'and': 1,
#   'Jack': 1},
#  'line 184': {'Were': 1,
#   'all': 1,
#   'of': 2,
#   'them': 1,
#   'locked': 1,
#   'up': 1,
#   'in': 1,
#   'coffins': 1,
#   'black': 1},
#  'line 186': {'And': 1,
#   'by': 1,
#   'came': 1,
#   'an': 1,
#   'angel': 1,
#   'who': 1,
#   'had': 1,
#   'a': 1,
#   'bright': 1,
#   'key': 1},
#  'line 187': {'And': 1,
#   'he': 1,
#   'opened': 1,
#   'the': 1,
#   'coffins': 1,
#   'and': 1,
#   'let': 1,
#   'them': 1,
#   'all': 1,
#   'free': 1},
#  'line 188': {'Then': 1,
#   'down': 1,
#   'a': 1,
#   'green': 1,
#   'plain': 1,
#   'leaping': 1,
#   'laughing': 1,
#   'they': 1,
#   'run': 1},
#  'line 189': {'And': 1,
#   'wash': 1,
#   'in': 2,
#   'a': 1,
#   'river': 1,
#   'and': 1,
#   'shine': 1,
#   'the': 1,
#   'sun': 1},
#  'line 191': {'Then': 1,
#   'naked': 1,
#   'and': 1,
#   'white': 1,
#   'all': 1,
#   'their': 1,
#   'bags': 1,
#   'left': 1,
#   'behind': 1},
#  'line 192': {'They': 1,
#   'rise': 1,
#   'upon': 1,
#   'clouds': 1,
#   'and': 1,
#   'sport': 1,
#   'in': 1,
#   'the': 1,
#   'wind': 1},
#  'line 193': {'And': 1,
#   'the': 1,
#   'Angel': 1,
#   'told': 1,
#   'Tom': 1,
#   'if': 1,
#   'he': 1,
#   'd': 1,
#   'be': 1,
#   'a': 1,
#   'good': 1,
#   'boy': 1},
#  'line 194': {'He': 1,
#   'd': 1,
#   'have': 1,
#   'God': 1,
#   'for': 1,
#   'his': 1,
#   'father': 1,
#   'and': 1,
#   'never': 1,
#   'want': 1,
#   'joy': 1},
#  'line 196': {'And': 1,
#   'so': 1,
#   'Tom': 1,
#   'awoke': 1,
#   'and': 1,
#   'we': 1,
#   'rose': 1,
#   'in': 1,
#   'the': 1,
#   'dark': 1},
#  'line 197': {'And': 1,
#   'got': 1,
#   'with': 1,
#   'our': 2,
#   'bags': 1,
#   'and': 1,
#   'brushes': 1,
#   'to': 1,
#   'work': 1},
#  'line 198': {'Though': 1,
#   'the': 1,
#   'morning': 1,
#   'was': 2,
#   'cold': 1,
#   'Tom': 1,
#   'happy': 1,
#   'and': 1,
#   'warm': 1},
#  'line 199': {'So': 1,
#   'if': 1,
#   'all': 1,
#   'do': 1,
#   'their': 1,
#   'duty': 1,
#   'they': 1,
#   'need': 1,
#   'not': 1,
#   'fear': 1,
#   'harm': 1},
#  'line 202': {'THE': 1, 'LITTLE': 1, 'BOY': 1, 'LOST': 1},
#  'line 204': {'Father': 1,
#   'father': 1,
#   'where': 1,
#   'are': 1,
#   'you': 1,
#   'going': 1},
#  'line 205': {'Oh': 1, 'do': 1, 'not': 1, 'walk': 1, 'so': 1, 'fast': 1},
#  'line 206': {'Speak': 1,
#   'father': 1,
#   'speak': 1,
#   'to': 1,
#   'you': 1,
#   'little': 1,
#   'boy': 1},
#  'line 207': {'Or': 1, 'else': 1, 'I': 1, 'shall': 1, 'be': 1, 'lost': 1},
#  'line 209': {'The': 1,
#   'night': 1,
#   'was': 2,
#   'dark': 1,
#   'no': 1,
#   'father': 1,
#   'there': 1},
#  'line 210': {'The': 1, 'child': 1, 'was': 1, 'wet': 1, 'with': 1, 'dew': 1},
#  'line 211': {'The': 1,
#   'mire': 1,
#   'was': 1,
#   'deep': 1,
#   'and': 1,
#   'the': 1,
#   'child': 1,
#   'did': 1,
#   'weep': 1},
#  'line 212': {'And': 1, 'away': 1, 'the': 1, 'vapour': 1, 'flew': 1},
#  'line 215': {'THE': 1, 'LITTLE': 1, 'BOY': 1, 'FOUND': 1},
#  'line 217': {'The': 1,
#   'little': 1,
#   'boy': 1,
#   'lost': 1,
#   'in': 1,
#   'the': 1,
#   'lonely': 1,
#   'fen': 1},
#  'line 218': {'Led': 1, 'by': 1, 'the': 1, 'wandering': 1, 'light': 1},
#  'line 219': {'Began': 1,
#   'to': 1,
#   'cry': 1,
#   'but': 1,
#   'God': 1,
#   'ever': 1,
#   'nigh': 1},
#  'line 220': {'Appeared': 1,
#   'like': 1,
#   'his': 1,
#   'father': 1,
#   'in': 1,
#   'white': 1},
#  'line 222': {'He': 1,
#   'kissed': 1,
#   'the': 2,
#   'child': 1,
#   'and': 1,
#   'by': 1,
#   'hand': 1,
#   'led': 1},
#  'line 223': {'And': 1, 'to': 1, 'his': 1, 'mother': 1, 'brought': 1},
#  'line 224': {'Who': 1,
#   'in': 1,
#   'sorrow': 1,
#   'pale': 1,
#   'through': 1,
#   'the': 1,
#   'lonely': 1,
#   'dale': 1},
#  'line 225': {'The': 1, 'little': 1, 'boy': 1, 'weeping': 1, 'sought': 1},
#  'line 228': {'LAUGHING': 1, 'SONG': 1},
#  'line 230': {'When': 1,
#   'the': 2,
#   'green': 1,
#   'woods': 1,
#   'laugh': 1,
#   'with': 1,
#   'voice': 1,
#   'of': 1,
#   'joy': 1},
#  'line 231': {'And': 1,
#   'the': 1,
#   'dimpling': 1,
#   'stream': 1,
#   'runs': 1,
#   'laughing': 1,
#   'by': 1},
#  'line 232': {'When': 1,
#   'the': 1,
#   'air': 1,
#   'does': 1,
#   'laugh': 1,
#   'with': 1,
#   'our': 1,
#   'merry': 1,
#   'wit': 1},
#  'line 233': {'And': 1,
#   'the': 2,
#   'green': 1,
#   'hill': 1,
#   'laughs': 1,
#   'with': 1,
#   'noise': 1,
#   'of': 1,
#   'it': 1},
#  'line 235': {'when': 1,
#   'the': 1,
#   'meadows': 1,
#   'laugh': 1,
#   'with': 1,
#   'lively': 1,
#   'green': 1},
#  'line 236': {'And': 1,
#   'the': 2,
#   'grasshopper': 1,
#   'laughs': 1,
#   'in': 1,
#   'merry': 1,
#   'scene': 1},
#  'line 237': {'When': 1, 'Mary': 1, 'and': 2, 'Susan': 1, 'Emily': 1},
#  'line 238': {'With': 1,
#   'their': 1,
#   'sweet': 1,
#   'round': 1,
#   'mouths': 1,
#   'sing': 1,
#   'Ha': 1,
#   'ha': 1,
#   'he': 1},
#  'line 240': {'When': 1,
#   'the': 2,
#   'painted': 1,
#   'birds': 1,
#   'laugh': 1,
#   'in': 1,
#   'shade': 1},
#  'line 241': {'Where': 1,
#   'our': 1,
#   'table': 1,
#   'with': 1,
#   'cherries': 1,
#   'and': 1,
#   'nuts': 1,
#   'is': 1,
#   'spread': 1},
#  'line 242': {'Come': 1,
#   'live': 1,
#   'and': 2,
#   'be': 1,
#   'merry': 1,
#   'join': 1,
#   'with': 1,
#   'me': 1},
#  'line 243': {'To': 1,
#   'sing': 1,
#   'the': 1,
#   'sweet': 1,
#   'chorus': 1,
#   'of': 1,
#   'Ha': 1,
#   'ha': 1,
#   'he': 1},
#  'line 246': {'A': 1, 'SONG': 1},
#  'line 248': {'Sweet': 1, 'dreams': 1, 'form': 1, 'a': 1, 'shade': 1},
#  'line 249': {'O': 1,
#   'er': 1,
#   'my': 1,
#   'lovely': 1,
#   'infant': 1,
#   's': 1,
#   'head': 1},
#  'line 250': {'Sweet': 1, 'dreams': 1, 'of': 1, 'pleasant': 1, 'streams': 1},
#  'line 251': {'By': 1, 'happy': 1, 'silent': 1, 'moony': 1, 'beams': 1},
#  'line 253': {'Sweet': 1, 'Sleep': 1, 'with': 1, 'soft': 1, 'down': 1},
#  'line 254': {'Weave': 1,
#   'thy': 1,
#   'brows': 1,
#   'an': 1,
#   'infant': 1,
#   'crown': 1},
#  'line 255': {'Sweet': 1, 'Sleep': 1, 'angel': 1, 'mild': 1},
#  'line 256': {'Hover': 1, 'o': 1, 'er': 1, 'my': 1, 'happy': 1, 'child': 1},
#  'line 258': {'Sweet': 1, 'smiles': 1, 'in': 1, 'the': 1, 'night': 1},
#  'line 259': {'Hover': 1, 'over': 1, 'my': 1, 'delight': 1},
#  'line 260': {'Sweet': 1, 'smiles': 1, 'mother': 1, 's': 1, 'smile': 1},
#  'line 261': {'All': 1, 'the': 1, 'livelong': 1, 'night': 1, 'beguile': 1},
#  'line 263': {'Sweet': 1, 'moans': 1, 'dovelike': 1, 'sighs': 1},
#  'line 264': {'Chase': 1,
#   'not': 1,
#   'slumber': 1,
#   'from': 1,
#   'thine': 1,
#   'eyes': 1},
#  'line 265': {'Sweet': 1, 'moan': 1, 'sweeter': 1, 'smile': 1},
#  'line 266': {'All': 1, 'the': 1, 'dovelike': 1, 'moans': 1, 'beguile': 1},
#  'line 268': {'Sleep': 1, 'sleep': 1, 'happy': 1, 'child': 1},
#  'line 269': {'All': 1, 'creation': 1, 'slept': 1, 'and': 1, 'smiled': 1},
#  'line 270': {'Sleep': 1, 'sleep': 2, 'happy': 1},
#  'line 271': {'While': 1,
#   'o': 1,
#   'er': 1,
#   'thee': 1,
#   'doth': 1,
#   'mother': 1,
#   'weep': 1},
#  'line 273': {'Sweet': 1, 'babe': 1, 'in': 1, 'thy': 1, 'face': 1},
#  'line 274': {'Holy': 1, 'image': 1, 'I': 1, 'can': 1, 'trace': 1},
#  'line 275': {'Sweet': 1, 'babe': 1, 'once': 1, 'like': 1, 'thee': 1},
#  'line 276': {'Thy': 1,
#   'Maker': 1,
#   'lay': 1,
#   'and': 1,
#   'wept': 1,
#   'for': 1,
#   'me': 1},
#  'line 278': {'Wept': 1, 'for': 3, 'me': 1, 'thee': 1, 'all': 1},
#  'line 279': {'When': 1, 'He': 1, 'was': 1, 'an': 1, 'infant': 1, 'small': 1},
#  'line 280': {'Thou': 1, 'His': 1, 'image': 1, 'ever': 1, 'see': 1},
#  'line 281': {'Heavenly': 1,
#   'face': 1,
#   'that': 1,
#   'smiles': 1,
#   'on': 1,
#   'thee': 1},
#  'line 283': {'Smiles': 1, 'on': 3, 'thee': 1, 'me': 1, 'all': 1},
#  'line 284': {'Who': 1, 'became': 1, 'an': 1, 'infant': 1, 'small': 1},
#  'line 285': {'Infant': 1, 'smiles': 2, 'are': 1, 'his': 1, 'own': 1},
#  'line 286': {'Heaven': 1,
#   'and': 1,
#   'earth': 1,
#   'to': 1,
#   'peace': 1,
#   'beguiles': 1},
#  'line 289': {'DIVINE': 1, 'IMAGE': 1},
#  'line 291': {'To': 1, 'Mercy': 1, 'Pity': 1, 'Peace': 1, 'and': 1, 'Love': 1},
#  'line 292': {'All': 1, 'pray': 1, 'in': 1, 'their': 1, 'distress': 1},
#  'line 293': {'And': 1,
#   'to': 1,
#   'these': 1,
#   'virtues': 1,
#   'of': 1,
#   'delight': 1},
#  'line 294': {'Return': 1, 'their': 1, 'thankfulness': 1},
#  'line 296': {'For': 1,
#   'Mercy': 1,
#   'Pity': 1,
#   'Peace': 1,
#   'and': 1,
#   'Love': 1},
#  'line 297': {'Is': 1, 'God': 1, 'our': 1, 'Father': 1, 'dear': 1},
#  'line 298': {'And': 1,
#   'Mercy': 1,
#   'Pity': 1,
#   'Peace': 1,
#   'and': 1,
#   'Love': 1},
#  'line 299': {'Is': 1, 'man': 1, 'his': 1, 'child': 1, 'and': 1, 'care': 1},
#  'line 301': {'For': 1, 'Mercy': 1, 'has': 1, 'a': 1, 'human': 1, 'heart': 1},
#  'line 302': {'Pity': 1, 'a': 1, 'human': 1, 'face': 1},
#  'line 303': {'And': 1,
#   'Love': 1,
#   'the': 1,
#   'human': 1,
#   'form': 1,
#   'divine': 1},
#  'line 304': {'And': 1, 'Peace': 1, 'the': 1, 'human': 1, 'dress': 1},
#  'line 306': {'Then': 1, 'every': 2, 'man': 1, 'of': 1, 'clime': 1},
#  'line 307': {'That': 1, 'prays': 1, 'in': 1, 'his': 1, 'distress': 1},
#  'line 308': {'Prays': 1,
#   'to': 1,
#   'the': 1,
#   'human': 1,
#   'form': 1,
#   'divine': 1},
#  'line 309': {'Love': 1, 'Mercy': 1, 'Pity': 1, 'Peace': 1},
#  'line 311': {'And': 1,
#   'all': 1,
#   'must': 1,
#   'love': 1,
#   'the': 1,
#   'human': 1,
#   'form': 1},
#  'line 312': {'In': 1, 'heathen': 1, 'Turk': 1, 'or': 1, 'Jew': 1},
#  'line 313': {'Where': 1,
#   'Mercy': 1,
#   'Love': 1,
#   'and': 1,
#   'Pity': 1,
#   'dwell': 1},
#  'line 314': {'There': 1, 'God': 1, 'is': 1, 'dwelling': 1, 'too': 1},
#  'line 317': {'HOLY': 1, 'THURSDAY': 1},
#  'line 319': {'Twas': 1,
#   'on': 1,
#   'a': 1,
#   'Holy': 1,
#   'Thursday': 1,
#   'their': 1,
#   'innocent': 1,
#   'faces': 1,
#   'clean': 1},
#  'line 320': {'Came': 1,
#   'children': 1,
#   'walking': 1,
#   'two': 2,
#   'and': 3,
#   'in': 1,
#   'read': 1,
#   'blue': 1,
#   'green': 1},
#  'line 321': {'Grey': 1,
#   'headed': 1,
#   'beadles': 1,
#   'walked': 1,
#   'before': 1,
#   'with': 1,
#   'wands': 1,
#   'as': 2,
#   'white': 1,
#   'snow': 1},
#  'line 322': {'Till': 1,
#   'into': 1,
#   'the': 1,
#   'high': 1,
#   'dome': 1,
#   'of': 1,
#   'Paul': 1,
#   's': 1,
#   'they': 1,
#   'like': 1,
#   'Thames': 1,
#   'waters': 1,
#   'flow': 1},
#  'line 324': {'Oh': 1,
#   'what': 1,
#   'a': 1,
#   'multitude': 1,
#   'they': 1,
#   'seemed': 1,
#   'these': 1,
#   'flowers': 1,
#   'of': 1,
#   'London': 1,
#   'town': 1},
#  'line 325': {'Seated': 1,
#   'in': 1,
#   'companies': 1,
#   'they': 1,
#   'sit': 1,
#   'with': 1,
#   'radiance': 1,
#   'all': 1,
#   'their': 1,
#   'own': 1},
#  'line 326': {'The': 1,
#   'hum': 1,
#   'of': 2,
#   'multitudes': 2,
#   'was': 1,
#   'there': 1,
#   'but': 1,
#   'lambs': 1},
#  'line 327': {'Thousands': 1,
#   'of': 1,
#   'little': 1,
#   'boys': 1,
#   'and': 1,
#   'girls': 1,
#   'raising': 1,
#   'their': 1,
#   'innocent': 1,
#   'hands': 1},
#  'line 329': {'Now': 1,
#   'like': 1,
#   'a': 1,
#   'mighty': 1,
#   'wild': 1,
#   'they': 1,
#   'raise': 1,
#   'to': 1,
#   'heaven': 1,
#   'the': 1,
#   'voice': 1,
#   'of': 1,
#   'song': 1},
#  'line 330': {'Or': 1,
#   'like': 1,
#   'harmonious': 1,
#   'thunderings': 1,
#   'the': 1,
#   'seats': 1,
#   'of': 1,
#   'heaven': 1,
#   'among': 1},
#  'line 331': {'Beneath': 1,
#   'them': 1,
#   'sit': 1,
#   'the': 2,
#   'aged': 1,
#   'man': 1,
#   'wise': 1,
#   'guardians': 1,
#   'of': 1,
#   'poor': 1},
#  'line 332': {'Then': 1,
#   'cherish': 1,
#   'pity': 1,
#   'lest': 1,
#   'you': 1,
#   'drive': 1,
#   'an': 1,
#   'angel': 1,
#   'from': 1,
#   'your': 1,
#   'door': 1},
#  'line 335': {'NIGHT': 1},
#  'line 337': {'The': 1,
#   'sun': 1,
#   'descending': 1,
#   'in': 1,
#   'the': 1,
#   'west': 1},
#  'line 338': {'The': 1, 'evening': 1, 'star': 1, 'does': 1, 'shine': 1},
#  'line 339': {'The': 1,
#   'birds': 1,
#   'are': 1,
#   'silent': 1,
#   'in': 1,
#   'their': 1,
#   'nest': 1},
#  'line 340': {'And': 1, 'I': 1, 'must': 1, 'seek': 1, 'for': 1, 'mine': 1},
#  'line 341': {'The': 1, 'moon': 1, 'like': 1, 'a': 1, 'flower': 1},
#  'line 342': {'In': 1, 'heaven': 1, 's': 1, 'high': 1, 'bower': 1},
#  'line 343': {'With': 1, 'silent': 1, 'delight': 1},
#  'line 344': {'Sits': 1, 'and': 1, 'smiles': 1, 'on': 1, 'the': 1, 'night': 1},
#  'line 346': {'Farewell': 1,
#   'green': 1,
#   'fields': 1,
#   'and': 1,
#   'happy': 1,
#   'grove': 1},
#  'line 347': {'Where': 1,
#   'flocks': 1,
#   'have': 1,
#   'ta': 1,
#   'en': 1,
#   'delight': 1},
#  'line 348': {'Where': 1,
#   'lambs': 1,
#   'have': 1,
#   'nibbled': 1,
#   'silent': 1,
#   'move': 1},
#  'line 349': {'The': 1, 'feet': 1, 'of': 1, 'angels': 1, 'bright': 1},
#  'line 350': {'Unseen': 1, 'they': 1, 'pour': 1, 'blessing': 1},
#  'line 351': {'And': 1, 'joy': 1, 'without': 1, 'ceasing': 1},
#  'line 352': {'On': 1, 'each': 1, 'bud': 1, 'and': 1, 'blossom': 1},
#  'line 353': {'And': 1, 'each': 1, 'sleeping': 1, 'bosom': 1},
#  'line 355': {'They': 1,
#   'look': 1,
#   'in': 1,
#   'every': 1,
#   'thoughtless': 1,
#   'nest': 1},
#  'line 356': {'Where': 1, 'birds': 1, 'are': 1, 'covered': 1, 'warm': 1},
#  'line 357': {'They': 1,
#   'visit': 1,
#   'caves': 1,
#   'of': 1,
#   'every': 1,
#   'beast': 1},
#  'line 358': {'To': 1, 'keep': 1, 'them': 1, 'all': 1, 'from': 1, 'harm': 1},
#  'line 359': {'If': 1, 'they': 1, 'see': 1, 'any': 1, 'weeping': 1},
#  'line 360': {'That': 1, 'should': 1, 'have': 1, 'been': 1, 'sleeping': 1},
#  'line 361': {'They': 1,
#   'pour': 1,
#   'sleep': 1,
#   'on': 1,
#   'their': 1,
#   'head': 1},
#  'line 362': {'And': 1, 'sit': 1, 'down': 1, 'by': 1, 'their': 1, 'bed': 1},
#  'line 364': {'When': 1,
#   'wolves': 1,
#   'and': 1,
#   'tigers': 1,
#   'howl': 1,
#   'for': 1,
#   'prey': 1},
#  'line 365': {'They': 1, 'pitying': 1, 'stand': 1, 'and': 1, 'weep': 1},
#  'line 366': {'Seeking': 1,
#   'to': 1,
#   'drive': 1,
#   'their': 1,
#   'thirst': 1,
#   'away': 1},
#  'line 367': {'And': 1, 'keep': 1, 'them': 1, 'from': 1, 'the': 1, 'sheep': 1},
#  'line 368': {'But': 1, 'if': 1, 'they': 1, 'rush': 1, 'dreadful': 1},
#  'line 369': {'The': 1, 'angels': 1, 'most': 1, 'heedful': 1},
#  'line 370': {'Receive': 1, 'each': 1, 'mild': 1, 'spirit': 1},
#  'line 371': {'New': 1, 'worlds': 1, 'to': 1, 'inherit': 1},
#  'line 374': {'And': 1,
#   'there': 1,
#   'the': 1,
#   'lion': 1,
#   's': 1,
#   'ruddy': 1,
#   'eyes': 1},
#  'line 375': {'Shall': 1,
#   'flow': 1,
#   'with': 1,
#   'tears': 1,
#   'of': 1,
#   'gold': 1},
#  'line 376': {'And': 1, 'pitying': 1, 'the': 1, 'tender': 1, 'cries': 1},
#  'line 377': {'And': 1, 'walking': 1, 'round': 1, 'the': 1, 'fold': 1},
#  'line 378': {'Saying': 1, 'Wrath': 1, 'by': 1, 'His': 1, 'meekness': 1},
#  'line 379': {'And': 1, 'by': 1, 'His': 1, 'health': 1, 'sickness': 1},
#  'line 380': {'Are': 1, 'driven': 1, 'away': 1},
#  'line 381': {'From': 1, 'our': 1, 'immortal': 1, 'day': 1},
#  'line 383': {'And': 1,
#   'now': 1,
#   'beside': 1,
#   'thee': 1,
#   'bleating': 1,
#   'lamb': 1},
#  'line 384': {'I': 1, 'can': 1, 'lie': 1, 'down': 1, 'and': 1, 'sleep': 1},
#  'line 385': {'Or': 1,
#   'think': 1,
#   'on': 1,
#   'Him': 1,
#   'who': 1,
#   'bore': 1,
#   'thy': 1,
#   'name': 1},
#  'line 386': {'Graze': 1, 'after': 1, 'thee': 1, 'and': 1, 'weep': 1},
#  'line 387': {'For': 1, 'washed': 1, 'in': 1, 'life': 1, 's': 1, 'river': 1},
#  'line 388': {'My': 1, 'bright': 1, 'mane': 1, 'for': 1, 'ever': 1},
#  'line 389': {'Shall': 1, 'shine': 1, 'like': 1, 'the': 1, 'gold': 1},
#  'line 390': {'As': 1,
#   'I': 1,
#   'guard': 1,
#   'o': 1,
#   'er': 1,
#   'the': 1,
#   'fold': 1},
#  'line 393': {'SPRING': 1},
#  'line 395': {'Sound': 1, 'the': 1, 'flute': 1},
#  'line 396': {'Now': 1, 'it': 1, 's': 1, 'mute': 1},
#  'line 397': {'Bird': 1, 's': 1, 'delight': 1},
#  'line 398': {'Day': 1, 'and': 1, 'night': 1},
#  'line 399': {'Nightingale': 1},
#  'line 400': {'In': 1, 'the': 1, 'dale': 1},
#  'line 401': {'Lark': 1, 'in': 1, 'sky': 1},
#  'line 402': {'Merrily': 1},
#  'line 403': {'Merrily': 1,
#   'merrily': 1,
#   'to': 1,
#   'welcome': 1,
#   'in': 1,
#   'the': 1,
#   'year': 1},
#  'line 405': {'Little': 1, 'boy': 1},
#  'line 406': {'Full': 1, 'of': 1, 'joy': 1},
#  'line 407': {'Little': 1, 'girl': 1},
#  'line 408': {'Sweet': 1, 'and': 1, 'small': 1},
#  'line 409': {'Cock': 1, 'does': 1, 'crow': 1},
#  'line 410': {'So': 1, 'do': 1, 'you': 1},
#  'line 411': {'Merry': 1, 'voice': 1},
#  'line 412': {'Infant': 1, 'noise': 1},
#  'line 413': {'Merrily': 1,
#   'merrily': 1,
#   'to': 1,
#   'welcome': 1,
#   'in': 1,
#   'the': 1,
#   'year': 1},
#  'line 415': {'Little': 1, 'lamb': 1},
#  'line 416': {'Here': 1, 'I': 1, 'am': 1},
#  'line 417': {'Come': 1, 'and': 1, 'lick': 1},
#  'line 418': {'My': 1, 'white': 1, 'neck': 1},
#  'line 419': {'Let': 1, 'me': 1, 'pull': 1},
#  'line 420': {'Your': 1, 'soft': 1, 'wool': 1},
#  'line 421': {'Let': 1, 'me': 1, 'kiss': 1},
#  'line 422': {'Your': 1, 'soft': 1, 'face': 1},
#  'line 426': {'NURSE': 1, 'S': 1, 'SONG': 1},
#  'line 428': {'When': 1,
#   'the': 2,
#   'voices': 1,
#   'of': 1,
#   'children': 1,
#   'are': 1,
#   'heard': 1,
#   'on': 1,
#   'green': 1},
#  'line 429': {'And': 1,
#   'laughing': 1,
#   'is': 1,
#   'heard': 1,
#   'on': 1,
#   'the': 1,
#   'hill': 1},
#  'line 430': {'My': 1,
#   'heart': 1,
#   'is': 1,
#   'at': 1,
#   'rest': 1,
#   'within': 1,
#   'my': 1,
#   'breast': 1},
#  'line 431': {'And': 1, 'everything': 1, 'else': 1, 'is': 1, 'still': 1},
#  'line 432': {'Then': 1,
#   'come': 1,
#   'home': 1,
#   'my': 1,
#   'children': 1,
#   'the': 1,
#   'sun': 1,
#   'is': 1,
#   'gone': 1,
#   'down': 1},
#  'line 433': {'And': 1, 'the': 1, 'dews': 1, 'of': 1, 'night': 1, 'arise': 1},
#  'line 434': {'Come': 1,
#   'come': 1,
#   'leave': 1,
#   'off': 1,
#   'play': 1,
#   'and': 1,
#   'let': 1,
#   'us': 1,
#   'away': 1},
#  'line 435': {'Till': 1,
#   'the': 2,
#   'morning': 1,
#   'appears': 1,
#   'in': 1,
#   'skies': 1},
#  'line 437': {'No': 1,
#   'no': 1,
#   'let': 1,
#   'us': 1,
#   'play': 1,
#   'for': 1,
#   'it': 1,
#   'is': 1,
#   'yet': 1,
#   'day': 1},
#  'line 438': {'And': 1, 'we': 1, 'cannot': 1, 'go': 1, 'to': 1, 'sleep': 1},
#  'line 439': {'Besides': 1,
#   'in': 1,
#   'the': 2,
#   'sky': 1,
#   'little': 1,
#   'birds': 1,
#   'fly': 1},
#  'line 440': {'And': 1,
#   'the': 1,
#   'hills': 1,
#   'are': 1,
#   'all': 1,
#   'covered': 1,
#   'with': 1,
#   'sheep': 1},
#  'line 441': {'Well': 1,
#   'well': 1,
#   'go': 1,
#   'and': 1,
#   'play': 1,
#   'till': 1,
#   'the': 1,
#   'light': 1,
#   'fades': 1,
#   'away': 1},
#  'line 442': {'And': 1, 'then': 1, 'go': 1, 'home': 1, 'to': 1, 'bed': 1},
#  'line 443': {'The': 1,
#   'little': 1,
#   'ones': 1,
#   'leaped': 1,
#   'and': 2,
#   'shouted': 1,
#   'laughed': 1},
#  'line 444': {'And': 1, 'all': 1, 'the': 1, 'hills': 1, 'echoed': 1},
#  'line 447': {'INFANT': 1, 'JOY': 1},
#  'line 449': {'I': 1, 'have': 1, 'no': 1, 'name': 1},
#  'line 450': {'I': 1, 'am': 1, 'but': 1, 'two': 1, 'days': 1, 'old': 1},
#  'line 451': {'What': 1, 'shall': 1, 'I': 1, 'call': 1, 'thee': 1},
#  'line 452': {'I': 1, 'happy': 1, 'am': 1},
#  'line 453': {'Joy': 1, 'is': 1, 'my': 1, 'name': 1},
#  'line 454': {'Sweet': 1, 'joy': 1, 'befall': 1, 'thee': 1},
#  'line 456': {'Pretty': 1, 'joy': 1},
#  'line 457': {'Sweet': 1, 'joy': 1, 'but': 1, 'two': 1, 'days': 1, 'old': 1},
#  'line 458': {'Sweet': 1, 'Joy': 1, 'I': 1, 'call': 1, 'thee': 1},
#  'line 459': {'Thou': 1, 'dost': 1, 'smile': 1},
#  'line 460': {'I': 1, 'sing': 1, 'the': 1, 'while': 1},
#  'line 464': {'A': 1, 'DREAM': 1},
#  'line 466': {'Once': 1, 'a': 2, 'dream': 1, 'did': 1, 'weave': 1, 'shade': 1},
#  'line 467': {'O': 1, 'er': 1, 'my': 1, 'angel': 1, 'guarded': 1, 'bed': 1},
#  'line 468': {'That': 1, 'an': 1, 'emmet': 1, 'lost': 1, 'its': 1, 'way': 1},
#  'line 469': {'Where': 1,
#   'on': 1,
#   'grass': 1,
#   'methought': 1,
#   'I': 1,
#   'lay': 1},
#  'line 471': {'Troubled': 1, 'wildered': 1, 'and': 1, 'forlorn': 1},
#  'line 472': {'Dark': 1, 'benighted': 1, 'travel': 1, 'worn': 1},
#  'line 473': {'Over': 1, 'many': 1, 'a': 1, 'tangle': 1, 'spray': 1},
#  'line 474': {'All': 1,
#   'heart': 1,
#   'broke': 1,
#   'I': 1,
#   'heard': 1,
#   'her': 1,
#   'say': 1},
#  'line 476': {'Oh': 1, 'my': 1, 'children': 1, 'do': 1, 'they': 1, 'cry': 1},
#  'line 477': {'Do': 1,
#   'they': 1,
#   'hear': 1,
#   'their': 1,
#   'father': 1,
#   'sigh': 1},
#  'line 478': {'Now': 1, 'they': 1, 'look': 1, 'abroad': 1, 'to': 1, 'see': 1},
#  'line 479': {'Now': 1, 'return': 1, 'and': 1, 'weep': 1, 'for': 1, 'me': 1},
#  'line 481': {'Pitying': 1, 'I': 1, 'dropped': 1, 'a': 1, 'tear': 1},
#  'line 482': {'But': 1,
#   'I': 1,
#   'saw': 1,
#   'a': 1,
#   'glow': 1,
#   'worm': 1,
#   'near': 1},
#  'line 483': {'Who': 1, 'replied': 1, 'What': 1, 'wailing': 1, 'wight': 1},
#  'line 484': {'Calls': 1, 'the': 2, 'watchman': 1, 'of': 1, 'night': 1},
#  'line 486': {'I': 1,
#   'am': 1,
#   'set': 1,
#   'to': 1,
#   'light': 1,
#   'the': 1,
#   'ground': 1},
#  'line 487': {'While': 1,
#   'the': 1,
#   'beetle': 1,
#   'goes': 1,
#   'his': 1,
#   'round': 1},
#  'line 488': {'Follow': 1, 'now': 1, 'the': 1, 'beetle': 1, 's': 1, 'hum': 1},
#  'line 489': {'Little': 1, 'wanderer': 1, 'hie': 1, 'thee': 1, 'home': 1},
#  'line 492': {'ON': 1, 'ANOTHER': 1, 'S': 1, 'SORROW': 1},
#  'line 494': {'Can': 1, 'I': 1, 'see': 1, 'another': 1, 's': 1, 'woe': 1},
#  'line 495': {'And': 1, 'not': 1, 'be': 1, 'in': 1, 'sorrow': 1, 'too': 1},
#  'line 496': {'Can': 1, 'I': 1, 'see': 1, 'another': 1, 's': 1, 'grief': 1},
#  'line 497': {'And': 1, 'not': 1, 'seek': 1, 'for': 1, 'kind': 1, 'relief': 1},
#  'line 499': {'Can': 1, 'I': 1, 'see': 1, 'a': 1, 'falling': 1, 'tear': 1},
#  'line 500': {'And': 1,
#   'not': 1,
#   'feel': 1,
#   'my': 1,
#   'sorrow': 1,
#   's': 1,
#   'share': 1},
#  'line 501': {'Can': 1, 'a': 1, 'father': 1, 'see': 1, 'his': 1, 'child': 1},
#  'line 502': {'Weep': 1,
#   'nor': 1,
#   'be': 1,
#   'with': 1,
#   'sorrow': 1,
#   'filled': 1},
#  'line 504': {'Can': 1, 'a': 1, 'mother': 1, 'sit': 1, 'and': 1, 'hear': 1},
#  'line 505': {'An': 1, 'infant': 2, 'groan': 1, 'an': 1, 'fear': 1},
#  'line 506': {'No': 1, 'no': 1, 'never': 1, 'can': 1, 'it': 1, 'be': 1},
#  'line 507': {'Never': 1, 'never': 1, 'can': 1, 'it': 1, 'be': 1},
#  'line 509': {'And': 1,
#   'can': 1,
#   'He': 1,
#   'who': 1,
#   'smiles': 1,
#   'on': 1,
#   'all': 1},
#  'line 510': {'Hear': 1,
#   'the': 1,
#   'wren': 1,
#   'with': 1,
#   'sorrows': 1,
#   'small': 1},
#  'line 511': {'Hear': 1,
#   'the': 1,
#   'small': 1,
#   'bird': 1,
#   's': 1,
#   'grief': 1,
#   'and': 1,
#   'care': 1},
#  'line 512': {'Hear': 1,
#   'the': 1,
#   'woes': 1,
#   'that': 1,
#   'infants': 1,
#   'bear': 1},
#  'line 514': {'And': 1, 'not': 1, 'sit': 1, 'beside': 1, 'the': 1, 'next': 1},
#  'line 515': {'Pouring': 1, 'pity': 1, 'in': 1, 'their': 1, 'breast': 1},
#  'line 516': {'And': 1, 'not': 1, 'sit': 1, 'the': 1, 'cradle': 1, 'near': 1},
#  'line 517': {'Weeping': 1, 'tear': 2, 'on': 1, 'infant': 1, 's': 1},
#  'line 519': {'And': 1,
#   'not': 1,
#   'sit': 1,
#   'both': 1,
#   'night': 1,
#   'and': 1,
#   'day': 1},
#  'line 520': {'Wiping': 1, 'all': 1, 'our': 1, 'tears': 1, 'away': 1},
#  'line 521': {'Oh': 1, 'no': 1, 'never': 1, 'can': 1, 'it': 1, 'be': 1},
#  'line 524': {'He': 1,
#   'doth': 1,
#   'give': 1,
#   'his': 1,
#   'joy': 1,
#   'to': 1,
#   'all': 1},
#  'line 525': {'He': 1, 'becomes': 1, 'an': 1, 'infant': 1, 'small': 1},
#  'line 526': {'He': 1, 'becomes': 1, 'a': 1, 'man': 1, 'of': 1, 'woe': 1},
#  'line 527': {'He': 1, 'doth': 1, 'feel': 1, 'the': 1, 'sorrow': 1, 'too': 1},
#  'line 529': {'Think': 1, 'not': 1, 'thou': 1, 'canst': 1, 'sigh': 2, 'a': 1},
#  'line 530': {'And': 1, 'thy': 1, 'Maker': 1, 'is': 1, 'not': 1, 'by': 1},
#  'line 531': {'Think': 1,
#   'not': 1,
#   'thou': 1,
#   'canst': 1,
#   'weep': 1,
#   'a': 1,
#   'tear': 1},
#  'line 532': {'And': 1, 'thy': 1, 'Maker': 1, 'is': 1, 'not': 1, 'year': 1},
#  'line 534': {'Oh': 1,
#   'He': 1,
#   'gives': 1,
#   'to': 1,
#   'us': 1,
#   'his': 1,
#   'joy': 1},
#  'line 535': {'That': 1,
#   'our': 1,
#   'grief': 1,
#   'He': 1,
#   'may': 1,
#   'destroy': 1},
#  'line 536': {'Till': 1,
#   'our': 1,
#   'grief': 1,
#   'is': 1,
#   'fled': 1,
#   'an': 1,
#   'gone': 1},
#  'line 537': {'He': 1,
#   'doth': 1,
#   'sit': 1,
#   'by': 1,
#   'us': 1,
#   'and': 1,
#   'moan': 1},
#  'line 540': {'SONGS': 1, 'OF': 1, 'EXPERIENCE': 1},
#  'line 545': {'Hear': 1, 'the': 2, 'voice': 1, 'of': 1, 'Bard': 1},
#  'line 546': {'Who': 1,
#   'present': 1,
#   'past': 1,
#   'and': 1,
#   'future': 1,
#   'sees': 1},
#  'line 547': {'Whose': 1, 'ears': 1, 'have': 1, 'heard': 1},
#  'line 548': {'The': 1, 'Holy': 1, 'Word': 1},
#  'line 549': {'That': 1,
#   'walked': 1,
#   'among': 1,
#   'the': 1,
#   'ancient': 1,
#   'tree': 1},
#  'line 551': {'Calling': 1, 'the': 1, 'lapsed': 1, 'soul': 1},
#  'line 552': {'And': 1,
#   'weeping': 1,
#   'in': 1,
#   'the': 1,
#   'evening': 1,
#   'dew': 1},
#  'line 553': {'That': 1, 'might': 1, 'control': 1},
#  'line 554': {'The': 1, 'starry': 1, 'pole': 1},
#  'line 555': {'And': 1, 'fallen': 2, 'light': 1, 'renew': 1},
#  'line 557': {'O': 2, 'Earth': 2, 'return': 1},
#  'line 558': {'Arise': 1,
#   'from': 1,
#   'out': 1,
#   'the': 1,
#   'dewy': 1,
#   'grass': 1},
#  'line 559': {'Night': 1, 'is': 1, 'worn': 1},
#  'line 560': {'And': 1, 'the': 1, 'morn': 1},
#  'line 561': {'Rises': 1, 'from': 1, 'the': 1, 'slumbrous': 1, 'mass': 1},
#  'line 563': {'Turn': 1, 'away': 1, 'no': 1, 'more': 1},
#  'line 564': {'Why': 1, 'wilt': 1, 'thou': 1, 'turn': 1, 'away': 1},
#  'line 565': {'The': 1, 'starry': 1, 'floor': 1},
#  'line 566': {'The': 1, 'watery': 1, 'shore': 1},
#  'line 567': {'Are': 1,
#   'given': 1,
#   'thee': 1,
#   'till': 1,
#   'the': 1,
#   'break': 1,
#   'of': 1,
#   'day': 1},
#  'line 570': {'EARTH': 1, 'S': 1, 'ANSWER': 1},
#  'line 572': {'Earth': 1, 'raised': 1, 'up': 1, 'her': 1, 'head': 1},
#  'line 573': {'From': 1,
#   'the': 1,
#   'darkness': 1,
#   'dread': 1,
#   'and': 1,
#   'drear': 1},
#  'line 574': {'Her': 1, 'light': 1, 'fled': 1},
#  'line 575': {'Stony': 1, 'dread': 1},
#  'line 576': {'And': 1,
#   'her': 1,
#   'locks': 1,
#   'covered': 1,
#   'with': 1,
#   'grey': 1,
#   'despair': 1},
#  'line 578': {'Prisoned': 1, 'on': 1, 'watery': 1, 'shore': 1},
#  'line 579': {'Starry': 1,
#   'jealousy': 1,
#   'does': 1,
#   'keep': 1,
#   'my': 1,
#   'den': 1},
#  'line 580': {'Cold': 1, 'and': 1, 'hoar': 1},
#  'line 581': {'Weeping': 1, 'o': 1, 're': 1},
#  'line 582': {'I': 1,
#   'hear': 1,
#   'the': 2,
#   'father': 1,
#   'of': 1,
#   'ancient': 1,
#   'men': 1},
#  'line 584': {'Selfish': 1, 'father': 1, 'of': 1, 'men': 1},
#  'line 585': {'Cruel': 1, 'jealous': 1, 'selfish': 1, 'fear': 1},
#  'line 586': {'Can': 1, 'delight': 1},
#  'line 587': {'Chained': 1, 'in': 1, 'night': 1},
#  'line 588': {'The': 1,
#   'virgins': 1,
#   'of': 1,
#   'youth': 1,
#   'and': 1,
#   'morning': 1,
#   'bear': 1},
#  'line 591': {'Does': 1, 'spring': 1, 'hide': 1, 'its': 1, 'joy': 1},
#  'line 592': {'When': 1, 'buds': 1, 'and': 1, 'blossoms': 1, 'grow': 1},
#  'line 593': {'Does': 1, 'the': 1, 'sower': 1},
#  'line 594': {'Sow': 1, 'by': 1, 'night': 1},
#  'line 595': {'Or': 1,
#   'the': 1,
#   'plowman': 1,
#   'in': 1,
#   'darkness': 1,
#   'plough': 1},
#  'line 597': {'Break': 1, 'this': 1, 'heavy': 1, 'chain': 1},
#  'line 598': {'That': 1,
#   'does': 1,
#   'freeze': 1,
#   'my': 1,
#   'bones': 1,
#   'around': 1},
#  'line 599': {'Selfish': 1, 'vain': 1},
#  'line 600': {'Eternal': 1, 'bane': 1},
#  'line 601': {'That': 1,
#   'free': 1,
#   'love': 1,
#   'with': 1,
#   'bondage': 1,
#   'bound': 1},
#  'line 604': {'THE': 2, 'CLOD': 1, 'AND': 1, 'PEBBLE': 1},
#  'line 606': {'Love': 1,
#   'seeketh': 1,
#   'not': 1,
#   'itself': 1,
#   'to': 1,
#   'please': 1},
#  'line 607': {'Nor': 1, 'for': 1, 'itself': 1, 'hath': 1, 'any': 1, 'care': 1},
#  'line 608': {'But': 1,
#   'for': 1,
#   'another': 1,
#   'gives': 1,
#   'it': 1,
#   'ease': 1},
#  'line 609': {'And': 1,
#   'builds': 1,
#   'a': 1,
#   'heaven': 1,
#   'in': 1,
#   'hell': 1,
#   's': 1,
#   'despair': 1},
#  'line 611': {'So': 1,
#   'sang': 1,
#   'a': 1,
#   'little': 1,
#   'clod': 1,
#   'of': 1,
#   'clay': 1},
#  'line 612': {'Trodden': 1,
#   'with': 1,
#   'the': 1,
#   'cattle': 1,
#   's': 1,
#   'feet': 1},
#  'line 613': {'But': 1, 'a': 1, 'pebble': 1, 'of': 1, 'the': 1, 'brook': 1},
#  'line 614': {'Warbled': 1, 'out': 1, 'these': 1, 'metres': 1, 'meet': 1},
#  'line 616': {'Love': 1,
#   'seeketh': 1,
#   'only': 1,
#   'Self': 1,
#   'to': 1,
#   'please': 1},
#  'line 617': {'To': 1,
#   'bind': 1,
#   'another': 1,
#   'to': 1,
#   'its': 1,
#   'delight': 1},
#  'line 618': {'Joys': 1,
#   'in': 1,
#   'another': 1,
#   's': 1,
#   'loss': 1,
#   'of': 1,
#   'ease': 1},
#  'line 619': {'And': 1,
#   'builds': 1,
#   'a': 1,
#   'hell': 1,
#   'in': 1,
#   'heaven': 1,
#   's': 1,
#   'despite': 1},
#  'line 624': {'Is': 1,
#   'this': 1,
#   'a': 1,
#   'holy': 1,
#   'thing': 1,
#   'to': 1,
#   'see': 1},
#  'line 625': {'In': 1, 'a': 1, 'rich': 1, 'and': 1, 'fruitful': 1, 'land': 1},
#  'line 626': {'Babes': 1, 'reduced': 1, 'to': 1, 'misery': 1},
#  'line 627': {'Fed': 1,
#   'with': 1,
#   'cold': 1,
#   'and': 1,
#   'usurous': 1,
#   'hand': 1},
#  'line 629': {'Is': 1, 'that': 1, 'trembling': 1, 'cry': 1, 'a': 1, 'song': 1},
#  'line 630': {'Can': 1,
#   'it': 1,
#   'be': 1,
#   'a': 1,
#   'song': 1,
#   'of': 1,
#   'joy': 1},
#  'line 631': {'And': 1, 'so': 1, 'many': 1, 'children': 1, 'poor': 1},
#  'line 632': {'It': 1, 'is': 1, 'a': 1, 'land': 1, 'of': 1, 'poverty': 1},
#  'line 634': {'And': 1,
#   'their': 1,
#   'son': 1,
#   'does': 1,
#   'never': 1,
#   'shine': 1},
#  'line 635': {'And': 1,
#   'their': 1,
#   'fields': 1,
#   'are': 1,
#   'bleak': 1,
#   'and': 1,
#   'bare': 1},
#  'line 636': {'And': 1,
#   'their': 1,
#   'ways': 1,
#   'are': 1,
#   'filled': 1,
#   'with': 1,
#   'thorns': 1},
#  'line 637': {'It': 1, 'is': 1, 'eternal': 1, 'winter': 1, 'there': 1},
#  'line 639': {'For': 1,
#   'where': 1,
#   'er': 1,
#   'the': 1,
#   'sun': 1,
#   'does': 1,
#   'shine': 1},
#  'line 640': {'And': 1,
#   'where': 1,
#   'er': 1,
#   'the': 1,
#   'rain': 1,
#   'does': 1,
#   'fall': 1},
#  'line 641': {'Babes': 1, 'should': 1, 'never': 1, 'hunger': 1, 'there': 1},
#  'line 642': {'Nor': 1, 'poverty': 1, 'the': 1, 'mind': 1, 'appall': 1},
#  'line 645': {'THE': 1, 'LITTLE': 1, 'GIRL': 1, 'LOST': 1},
#  'line 647': {'In': 1, 'futurity': 1},
#  'line 648': {'I': 1, 'prophetic': 1, 'see': 1},
#  'line 649': {'That': 1, 'the': 1, 'earth': 1, 'from': 1, 'sleep': 1},
#  'line 650': {'Grave': 1, 'the': 1, 'sentence': 1, 'deep': 1},
#  'line 652': {'Shall': 1, 'arise': 1, 'and': 1, 'seek': 1},
#  'line 653': {'for': 1, 'her': 1, 'Maker': 1, 'meek': 1},
#  'line 654': {'And': 1, 'the': 1, 'desert': 1, 'wild': 1},
#  'line 655': {'Become': 1, 'a': 1, 'garden': 1, 'mild': 1},
#  'line 657': {'In': 1, 'the': 1, 'southern': 1, 'clime': 1},
#  'line 658': {'Where': 1, 'the': 1, 'summer': 1, 's': 1, 'prime': 1},
#  'line 659': {'Never': 1, 'fades': 1, 'away': 1},
#  'line 660': {'Lovely': 1, 'Lyca': 1, 'lay': 1},
#  'line 662': {'Seven': 1, 'summers': 1, 'old': 1},
#  'line 663': {'Lovely': 1, 'Lyca': 1, 'told': 1},
#  'line 664': {'She': 1, 'had': 1, 'wandered': 1, 'long': 1},
#  'line 665': {'Hearing': 1, 'wild': 1, 'birds': 1, 'song': 1},
#  'line 667': {'Sweet': 1, 'sleep': 1, 'come': 1, 'to': 1, 'me': 1},
#  'line 668': {'Underneath': 1, 'this': 1, 'tree': 1},
#  'line 669': {'Do': 1, 'father': 1, 'mother': 1, 'weep': 1},
#  'line 670': {'Where': 1, 'can': 1, 'Lyca': 1, 'sleep': 1},
#  'line 672': {'Lost': 1, 'in': 1, 'desert': 1, 'wild': 1},
#  'line 673': {'Is': 1, 'your': 1, 'little': 1, 'child': 1},
#  'line 674': {'How': 1, 'can': 1, 'Lyca': 1, 'sleep': 1},
#  'line 675': {'If': 1, 'her': 1, 'mother': 1, 'weep': 1},
#  'line 677': {'If': 1, 'her': 1, 'heart': 1, 'does': 1, 'ache': 1},
#  'line 678': {'Then': 1, 'let': 1, 'Lyca': 1, 'wake': 1},
#  'line 679': {'If': 1, 'my': 1, 'mother': 1, 'sleep': 1},
#  'line 680': {'Lyca': 1, 'shall': 1, 'not': 1, 'weep': 1},
#  'line 682': {'Frowning': 1, 'frowning': 1, 'night': 1},
#  'line 683': {'O': 1, 'er': 1, 'this': 1, 'desert': 1, 'bright': 1},
#  'line 684': {'Let': 1, 'thy': 1, 'moon': 1, 'arise': 1},
#  'line 685': {'While': 1, 'I': 1, 'close': 1, 'my': 1, 'eyes': 1},
#  'line 687': {'Sleeping': 1, 'Lyca': 1, 'lay': 1},
#  'line 688': {'While': 1, 'the': 1, 'beasts': 1, 'of': 1, 'prey': 1},
#  'line 689': {'Come': 1, 'from': 1, 'caverns': 1, 'deep': 1},
#  'line 690': {'Viewed': 1, 'the': 1, 'maid': 1, 'asleep': 1},
#  'line 692': {'The': 1, 'kingly': 1, 'lion': 1, 'stood': 1},
#  'line 693': {'And': 1, 'the': 1, 'virgin': 1, 'viewed': 1},
#  'line 694': {'Then': 1, 'he': 1, 'gambolled': 1, 'round': 1},
#  'line 695': {'O': 1, 'er': 1, 'the': 1, 'hallowed': 1, 'ground': 1},
#  'line 697': {'Leopards': 1, 'tigers': 1, 'play': 1},
#  'line 698': {'Round': 1, 'her': 1, 'as': 1, 'she': 1, 'lay': 1},
#  'line 699': {'While': 1, 'the': 1, 'lion': 1, 'old': 1},
#  'line 700': {'Bowed': 1, 'his': 1, 'mane': 1, 'of': 1, 'gold': 1},
#  'line 702': {'And': 1, 'her': 1, 'breast': 1, 'did': 1, 'lick': 1},
#  'line 703': {'And': 1, 'upon': 1, 'her': 1, 'neck': 1},
#  'line 704': {'From': 1, 'his': 1, 'eyes': 1, 'of': 1, 'flame': 1},
#  'line 705': {'Ruby': 1, 'tears': 1, 'there': 1, 'came': 1},
#  'line 707': {'While': 1, 'the': 1, 'lioness': 1},
#  'line 708': {'Loosed': 1, 'her': 1, 'slender': 1, 'dress': 1},
#  'line 709': {'And': 1, 'naked': 1, 'they': 1, 'conveyed': 1},
#  'line 710': {'To': 1, 'caves': 1, 'the': 1, 'sleeping': 1, 'maid': 1},
#  'line 713': {'THE': 1, 'LITTLE': 1, 'GIRL': 1, 'FOUND': 1},
#  'line 715': {'All': 1, 'the': 1, 'night': 1, 'in': 1, 'woe': 1},
#  'line 716': {'Lyca': 1, 's': 1, 'parents': 1, 'go': 1},
#  'line 717': {'Over': 1, 'valleys': 1, 'deep': 1},
#  'line 718': {'While': 1, 'the': 1, 'deserts': 1, 'weep': 1},
#  'line 720': {'Tired': 1, 'and': 1, 'woe': 1, 'begone': 1},
#  'line 721': {'Hoarse': 1, 'with': 1, 'making': 1, 'moan': 1},
#  'line 722': {'Arm': 1, 'in': 1, 'arm': 1, 'seven': 1, 'days': 1},
#  'line 723': {'They': 1, 'traced': 1, 'the': 1, 'desert': 1, 'ways': 1},
#  'line 725': {'Seven': 1, 'nights': 1, 'they': 1, 'sleep': 1},
#  'line 726': {'Among': 1, 'shadows': 1, 'deep': 1},
#  'line 727': {'And': 1,
#   'dream': 1,
#   'they': 1,
#   'see': 1,
#   'their': 1,
#   'child': 1},
#  'line 728': {'Starved': 1, 'in': 1, 'desert': 1, 'wild': 1},
#  'line 730': {'Pale': 1, 'through': 1, 'pathless': 1, 'ways': 1},
#  'line 731': {'The': 1, 'fancied': 1, 'image': 1, 'strays': 1},
#  'line 732': {'Famished': 1, 'weeping': 1, 'weak': 1},
#  'line 733': {'With': 1, 'hollow': 1, 'piteous': 1, 'shriek': 1},
#  'line 735': {'Rising': 1, 'from': 1, 'unrest': 1},
#  'line 736': {'The': 1, 'trembling': 1, 'woman': 1, 'presse': 1},
#  'line 737': {'With': 1, 'feet': 1, 'of': 1, 'weary': 1, 'woe': 1},
#  'line 738': {'She': 1, 'could': 1, 'no': 1, 'further': 1, 'go': 1},
#  'line 740': {'In': 1, 'his': 1, 'arms': 1, 'he': 1, 'bore': 1},
#  'line 741': {'Her': 1, 'armed': 1, 'with': 1, 'sorrow': 1, 'sore': 1},
#  'line 742': {'Till': 1, 'before': 1, 'their': 1, 'way': 1},
#  'line 743': {'A': 1, 'couching': 1, 'lion': 1, 'lay': 1},
#  'line 745': {'Turning': 1, 'back': 1, 'was': 1, 'vain': 1},
#  'line 746': {'Soon': 1, 'his': 1, 'heavy': 1, 'mane': 1},
#  'line 747': {'Bore': 1, 'them': 1, 'to': 1, 'the': 1, 'ground': 1},
#  'line 748': {'Then': 1, 'he': 1, 'stalked': 1, 'around': 1},
#  'line 750': {'Smelling': 1, 'to': 1, 'his': 1, 'prey': 1},
#  'line 751': {'But': 1, 'their': 1, 'fears': 1, 'allay': 1},
#  'line 752': {'When': 1, 'he': 1, 'licks': 1, 'their': 1, 'hands': 1},
#  'line 753': {'And': 1, 'silent': 1, 'by': 1, 'them': 1, 'stands': 1},
#  'line 755': {'They': 1, 'look': 1, 'upon': 1, 'his': 1, 'eyes': 1},
#  'line 756': {'Filled': 1, 'with': 1, 'deep': 1, 'surprise': 1},
#  'line 757': {'And': 1, 'wondering': 1, 'behold': 1},
#  'line 758': {'A': 1, 'spirit': 1, 'armed': 1, 'in': 1, 'gold': 1},
#  'line 760': {'On': 1, 'his': 1, 'head': 1, 'a': 1, 'crown': 1},
#  'line 761': {'On': 1, 'his': 1, 'shoulders': 1, 'down': 1},
#  'line 762': {'Flowed': 1, 'his': 1, 'golden': 1, 'hair': 1},
#  'line 763': {'Gone': 1, 'was': 1, 'all': 1, 'their': 1, 'care': 1},
#  'line 765': {'Follow': 1, 'me': 1, 'he': 1, 'said': 1},
#  'line 766': {'Weep': 1, 'not': 1, 'for': 1, 'the': 1, 'maid': 1},
#  'line 767': {'In': 1, 'my': 1, 'palace': 1, 'deep': 1},
#  'line 768': {'Lyca': 1, 'lies': 1, 'asleep': 1},
#  'line 770': {'Then': 1, 'they': 1, 'followed': 1},
#  'line 771': {'Where': 1, 'the': 1, 'vision': 1, 'led': 1},
#  'line 772': {'And': 1, 'saw': 1, 'their': 1, 'sleeping': 1, 'child': 1},
#  'line 773': {'Among': 1, 'tigers': 1, 'wild': 1},
#  'line 775': {'To': 1, 'this': 1, 'day': 1, 'they': 1, 'dwell': 1},
#  'line 776': {'In': 1, 'a': 1, 'lonely': 1, 'dell': 1},
#  'line 777': {'Nor': 1, 'fear': 1, 'the': 1, 'wolvish': 1, 'howl': 1},
#  'line 778': {'Nor': 1, 'the': 1, 'lion': 1, 's': 1, 'growl': 1},
#  'line 781': {'THE': 1, 'CHIMNEY': 1, 'SWEEPER': 1},
#  'line 783': {'A': 1,
#   'little': 1,
#   'black': 1,
#   'thing': 1,
#   'in': 1,
#   'the': 1,
#   'snow': 1},
#  'line 784': {'Crying': 1, 'weep': 2, 'in': 1, 'notes': 1, 'of': 1, 'woe': 1},
#  'line 785': {'Where': 1,
#   'are': 1,
#   'thy': 1,
#   'father': 1,
#   'and': 1,
#   'mother': 1,
#   'Say': 1},
#  'line 786': {'They': 1,
#   'are': 1,
#   'both': 1,
#   'gone': 1,
#   'up': 1,
#   'to': 2,
#   'the': 1,
#   'church': 1,
#   'pray': 1},
#  'line 788': {'Because': 1,
#   'I': 1,
#   'was': 1,
#   'happy': 1,
#   'upon': 1,
#   'the': 1,
#   'heath': 1},
#  'line 789': {'And': 1,
#   'smiled': 1,
#   'among': 1,
#   'the': 1,
#   'winter': 1,
#   's': 1,
#   'snow': 1},
#  'line 790': {'They': 1,
#   'clothed': 1,
#   'me': 1,
#   'in': 1,
#   'the': 1,
#   'clothes': 1,
#   'of': 1,
#   'death': 1},
#  'line 791': {'And': 1,
#   'taught': 1,
#   'me': 1,
#   'to': 1,
#   'sing': 1,
#   'the': 1,
#   'notes': 1,
#   'of': 1,
#   'woe': 1},
#  'line 793': {'And': 1,
#   'because': 1,
#   'I': 1,
#   'am': 1,
#   'happy': 1,
#   'and': 2,
# ...
#   'delight': 1},
#  'line 1132': {'Once': 1, 'a': 1, 'youthful': 1, 'pair': 1},
#  'line 1133': {'Filled': 1, 'with': 1, 'softest': 1, 'care': 1},
#  'line 1134': {'Met': 1, 'in': 1, 'garden': 1, 'bright': 1},
#  'line 1135': {'Where': 1, 'the': 1, 'holy': 1, 'light': 1},
#  'line 1136': {'Had': 1,
#   'just': 1,
#   'removed': 1,
#   'the': 2,
#   'curtains': 1,
#   'of': 1,
#   'night': 1},
#  'line 1138': {'Then': 1, 'in': 1, 'rising': 1, 'day': 1},
#  'line 1139': {'On': 1, 'the': 1, 'grass': 1, 'they': 1, 'play': 1},
#  'line 1140': {'Parents': 1, 'were': 1, 'afar': 1},
#  'line 1141': {'Strangers': 1, 'came': 1, 'not': 1, 'near': 1},
#  'line 1142': {'And': 1,
#   'the': 1,
#   'maiden': 1,
#   'soon': 1,
#   'forgot': 1,
#   'her': 1,
#   'fear': 1},
#  'line 1144': {'Tired': 1, 'with': 1, 'kisses': 1, 'sweet': 1},
#  'line 1145': {'They': 1, 'agree': 1, 'to': 1, 'meet': 1},
#  'line 1146': {'When': 1, 'the': 1, 'silent': 1, 'sleep': 1},
#  'line 1147': {'Waves': 1, 'o': 1, 'er': 1, 'heaven': 1, 's': 1, 'deep': 1},
#  'line 1148': {'And': 1,
#   'the': 1,
#   'weary': 1,
#   'tired': 1,
#   'wanderers': 1,
#   'weep': 1},
#  'line 1150': {'To': 1, 'her': 1, 'father': 1, 'white': 1},
#  'line 1151': {'Came': 1, 'the': 1, 'maiden': 1, 'bright': 1},
#  'line 1152': {'But': 1, 'his': 1, 'loving': 1, 'look': 1},
#  'line 1153': {'Like': 1, 'the': 1, 'holy': 1, 'book': 1},
#  'line 1154': {'All': 1,
#   'her': 1,
#   'tender': 1,
#   'limbs': 1,
#   'with': 1,
#   'terror': 1,
#   'shook': 1},
#  'line 1156': {'Ona': 1, 'pale': 1, 'and': 1, 'weak': 1},
#  'line 1157': {'To': 1, 'thy': 1, 'father': 1, 'speak': 1},
#  'line 1158': {'Oh': 1, 'the': 1, 'trembling': 1, 'fear': 1},
#  'line 1159': {'Oh': 1, 'the': 1, 'dismal': 1, 'care': 1},
#  'line 1160': {'That': 1,
#   'shakes': 1,
#   'the': 1,
#   'blossoms': 1,
#   'of': 1,
#   'my': 1,
#   'hoary': 1,
#   'hair': 1},
#  'line 1163': {'THE': 1, 'SCHOOLBOY': 1},
#  'line 1165': {'I': 1,
#   'love': 1,
#   'to': 1,
#   'rise': 1,
#   'on': 1,
#   'a': 1,
#   'summer': 1,
#   'morn': 1},
#  'line 1166': {'When': 1,
#   'birds': 1,
#   'are': 1,
#   'singing': 1,
#   'on': 1,
#   'every': 1,
#   'tree': 1},
#  'line 1167': {'The': 1,
#   'distant': 1,
#   'huntsman': 1,
#   'winds': 1,
#   'his': 1,
#   'horn': 1},
#  'line 1168': {'And': 1,
#   'the': 1,
#   'skylark': 1,
#   'sings': 1,
#   'with': 1,
#   'me': 1},
#  'line 1169': {'Oh': 1, 'what': 1, 'sweet': 1, 'company': 1},
#  'line 1171': {'But': 1,
#   'to': 2,
#   'go': 1,
#   'school': 1,
#   'in': 1,
#   'a': 1,
#   'summer': 1,
#   'morn': 1},
#  'line 1172': {'Oh': 1, 'it': 1, 'drives': 1, 'all': 1, 'joy': 1, 'away': 1},
#  'line 1173': {'Under': 1, 'a': 1, 'cruel': 1, 'eye': 1, 'outworn': 1},
#  'line 1174': {'The': 1,
#   'little': 1,
#   'ones': 1,
#   'spend': 1,
#   'the': 1,
#   'day': 1},
#  'line 1175': {'In': 1, 'sighing': 1, 'and': 1, 'dismay': 1},
#  'line 1177': {'Ah': 1,
#   'then': 1,
#   'at': 1,
#   'times': 1,
#   'I': 1,
#   'drooping': 1,
#   'sit': 1},
#  'line 1178': {'And': 1,
#   'spend': 1,
#   'many': 1,
#   'an': 1,
#   'anxious': 1,
#   'hour': 1},
#  'line 1179': {'Nor': 1,
#   'in': 1,
#   'my': 1,
#   'book': 1,
#   'can': 1,
#   'I': 1,
#   'take': 1,
#   'delight': 1},
#  'line 1180': {'Nor': 1, 'sit': 1, 'in': 1, 'learning': 1, 's': 1, 'bower': 1},
#  'line 1181': {'Worn': 1,
#   'through': 1,
#   'with': 1,
#   'the': 1,
#   'dreary': 1,
#   'shower': 1},
#  'line 1183': {'How': 1,
#   'can': 1,
#   'the': 1,
#   'bird': 1,
#   'that': 1,
#   'is': 1,
#   'born': 1,
#   'for': 1,
#   'joy': 1},
#  'line 1184': {'Sit': 1, 'in': 1, 'a': 1, 'cage': 1, 'and': 1, 'sing': 1},
#  'line 1185': {'How': 1,
#   'can': 1,
#   'a': 1,
#   'child': 1,
#   'when': 1,
#   'fears': 1,
#   'annoy': 1},
#  'line 1186': {'But': 1, 'droop': 1, 'his': 1, 'tender': 1, 'wing': 1},
#  'line 1187': {'And': 1, 'forget': 1, 'his': 1, 'youthful': 1, 'spring': 1},
#  'line 1189': {'Oh': 1,
#   'father': 1,
#   'and': 1,
#   'mother': 1,
#   'if': 1,
#   'buds': 1,
#   'are': 1,
#   'nipped': 1},
#  'line 1190': {'And': 1, 'blossoms': 1, 'blown': 1, 'away': 1},
#  'line 1191': {'And': 1,
#   'if': 1,
#   'the': 1,
#   'tender': 1,
#   'plants': 1,
#   'are': 1,
#   'stripped': 1},
#  'line 1192': {'Of': 1,
#   'their': 1,
#   'joy': 1,
#   'in': 1,
#   'the': 1,
#   'springing': 1,
#   'day': 1},
#  'line 1193': {'By': 1, 'sorrow': 1, 'and': 1, 'care': 1, 's': 1, 'dismay': 1},
#  'line 1195': {'How': 1,
#   'shall': 1,
#   'the': 1,
#   'summer': 1,
#   'arise': 1,
#   'in': 1,
#   'joy': 1},
#  'line 1196': {'Or': 1, 'the': 1, 'summer': 1, 'fruits': 1, 'appear': 1},
#  'line 1197': {'Or': 1,
#   'how': 1,
#   'shall': 1,
#   'we': 1,
#   'gather': 1,
#   'what': 1,
#   'griefs': 1,
#   'destroy': 1},
#  'line 1198': {'Or': 1, 'bless': 1, 'the': 1, 'mellowing': 1, 'year': 1},
#  'line 1199': {'When': 1,
#   'the': 1,
#   'blasts': 1,
#   'of': 1,
#   'winter': 1,
#   'appear': 1},
#  'line 1202': {'TO': 1, 'TERZAH': 1},
#  'line 1204': {'Whate': 1,
#   'er': 1,
#   'is': 1,
#   'born': 1,
#   'of': 1,
#   'mortal': 1,
#   'birth': 1},
#  'line 1205': {'Must': 1,
#   'be': 1,
#   'consumed': 1,
#   'with': 1,
#   'the': 1,
#   'earth': 1},
#  'line 1206': {'To': 1, 'rise': 1, 'from': 1, 'generation': 1, 'free': 1},
#  'line 1207': {'Then': 1,
#   'what': 1,
#   'have': 1,
#   'I': 1,
#   'to': 1,
#   'do': 1,
#   'with': 1,
#   'thee': 1},
#  'line 1208': {'The': 1,
#   'sexes': 1,
#   'sprang': 1,
#   'from': 1,
#   'shame': 1,
#   'and': 1,
#   'pride': 1},
#  'line 1209': {'Blown': 1,
#   'in': 2,
#   'the': 1,
#   'morn': 1,
#   'evening': 1,
#   'died': 1},
#  'line 1210': {'But': 1,
#   'mercy': 1,
#   'changed': 1,
#   'death': 1,
#   'into': 1,
#   'sleep': 1},
#  'line 1211': {'The': 1,
#   'sexes': 1,
#   'rose': 1,
#   'to': 1,
#   'work': 1,
#   'and': 1,
#   'weep': 1},
#  'line 1213': {'Thou': 1,
#   'mother': 1,
#   'of': 1,
#   'my': 1,
#   'mortal': 1,
#   'part': 1},
#  'line 1214': {'With': 1,
#   'cruelty': 1,
#   'didst': 1,
#   'mould': 1,
#   'my': 1,
#   'heart': 1},
#  'line 1215': {'And': 1,
#   'with': 1,
#   'false': 1,
#   'self': 1,
#   'deceiving': 1,
#   'tears': 1},
#  'line 1216': {'Didst': 1,
#   'bind': 1,
#   'my': 1,
#   'nostrils': 1,
#   'eyes': 1,
#   'and': 1,
#   'ears': 1},
#  'line 1218': {'Didst': 1,
#   'close': 1,
#   'my': 1,
#   'tongue': 1,
#   'in': 1,
#   'senseless': 1,
#   'clay': 1},
#  'line 1219': {'And': 1,
#   'me': 1,
#   'to': 1,
#   'mortal': 1,
#   'life': 1,
#   'betray': 1},
#  'line 1220': {'The': 1,
#   'death': 1,
#   'of': 1,
#   'Jesus': 1,
#   'set': 1,
#   'me': 1,
#   'free': 1},
#  'line 1224': {'THE': 2, 'VOICE': 1, 'OF': 1, 'ANCIENT': 1, 'BARD': 1},
#  'line 1226': {'Youth': 1, 'of': 1, 'delight': 1, 'come': 1, 'hither': 1},
#  'line 1227': {'And': 1, 'see': 1, 'the': 1, 'opening': 1, 'morn': 1},
#  'line 1228': {'Image': 1, 'of': 1, 'Truth': 1, 'new': 1, 'born': 1},
#  'line 1229': {'Doubt': 1,
#   'is': 1,
#   'fled': 1,
#   'and': 1,
#   'clouds': 1,
#   'of': 1,
#   'reason': 1},
#  'line 1230': {'Dark': 1, 'disputes': 1, 'and': 1, 'artful': 1, 'teazing': 1},
#  'line 1231': {'Folly': 1, 'is': 1, 'an': 1, 'endless': 1, 'maze': 1},
#  'line 1232': {'Tangled': 1, 'roots': 1, 'perplex': 1, 'her': 1, 'ways': 1},
#  'line 1233': {'How': 1, 'many': 1, 'have': 1, 'fallen': 1, 'there': 1},
#  'line 1234': {'They': 1,
#   'stumble': 1,
#   'all': 1,
#   'night': 1,
#   'over': 1,
#   'bones': 1,
#   'of': 1,
#   'the': 1,
#   'dead': 1},
#  'line 1235': {'And': 1,
#   'feel': 1,
#   'they': 1,
#   'know': 1,
#   'not': 1,
#   'what': 1,
#   'but': 1,
#   'care': 1},
#  'line 1236': {'And': 1,
#   'wish': 1,
#   'to': 1,
#   'lead': 1,
#   'others': 1,
#   'when': 1,
#   'they': 1,
#   'should': 1,
#   'be': 1,
#   'led': 1},
#  'line 1239': {'APPENDIX': 1},
#  'line 1241': {'A': 1, 'DIVINE': 1, 'IMAGE': 1},
#  'line 1243': {'Cruelty': 1, 'has': 1, 'a': 1, 'human': 1, 'heart': 1},
#  'line 1244': {'And': 1, 'Jealousy': 1, 'a': 1, 'human': 1, 'face': 1},
#  'line 1245': {'Terror': 1, 'the': 1, 'human': 1, 'form': 1, 'divine': 1},
#  'line 1246': {'And': 1, 'Secresy': 1, 'the': 1, 'human': 1, 'dress': 1},
#  'line 1248': {'The': 1,
#   'human': 1,
#   'dress': 1,
#   'is': 1,
#   'forged': 1,
#   'iron': 1},
#  'line 1249': {'The': 1,
#   'human': 1,
#   'form': 1,
#   'a': 1,
#   'fiery': 1,
#   'forge': 1},
#  'line 1250': {'The': 1,
#   'human': 1,
#   'face': 1,
#   'a': 1,
#   'furnace': 1,
#   'sealed': 1},
#  'line 1251': {'The': 1,
#   'human': 1,
#   'heart': 1,
#   'its': 1,
#   'hungry': 1,
#   'gorge': 1},
#  'line 1253': {'NOTE': 1,
#   'Though': 1,
#   'written': 1,
#   'and': 1,
#   'engraved': 1,
#   'by': 1,
#   'Blake': 1,
#   'A': 1,
#   'DIVINE': 1,
#   'IMAGE': 1,
#   'was': 1,
#   'never': 1},
#  'line 1254': {'included': 1,
#   'in': 1,
#   'the': 1,
#   'SONGS': 1,
#   'OF': 2,
#   'INNOCENCE': 1,
#   'AND': 1,
#   'EXPERIENCE': 1},
#  'line 1261': {'William': 1, 'Blake': 1, 's': 1},
#  'line 1263': {'THE': 1, 'BOOK': 1, 'of': 1, 'THEL': 1},
#  'line 1266': {'THEL': 1, 'S': 1, 'Motto': 1},
#  'line 1268': {'Does': 1,
#   'the': 2,
#   'Eagle': 1,
#   'know': 1,
#   'what': 1,
#   'is': 1,
#   'in': 1,
#   'pit': 1},
#  'line 1269': {'Or': 1,
#   'wilt': 1,
#   'thou': 1,
#   'go': 1,
#   'ask': 1,
#   'the': 1,
#   'Mole': 1},
#  'line 1270': {'Can': 1,
#   'Wisdom': 1,
#   'be': 1,
#   'put': 1,
#   'in': 1,
#   'a': 1,
#   'silver': 1,
#   'rod': 1},
#  'line 1271': {'Or': 1, 'Love': 1, 'in': 1, 'a': 1, 'golden': 1, 'bowl': 1},
#  'line 1276': {'The': 1,
#   'Author': 1,
#   'Printer': 1,
#   'Willm': 1,
#   'Blake': 1,
#   '1780': 1},
#  'line 1279': {'THEL': 1},
#  'line 1281': {'I': 1},
#  'line 1283': {'The': 1,
#   'daughters': 1,
#   'of': 1,
#   'Mne': 1,
#   'Seraphim': 1,
#   'led': 1,
#   'round': 1,
#   'their': 1,
#   'sunny': 1,
#   'flocks': 1},
#  'line 1284': {'All': 1,
#   'but': 1,
#   'the': 2,
#   'youngest': 1,
#   'she': 1,
#   'in': 1,
#   'paleness': 1,
#   'sought': 1,
#   'secret': 1,
#   'air': 1},
#  'line 1285': {'To': 1,
#   'fade': 1,
#   'away': 1,
#   'like': 1,
#   'morning': 1,
#   'beauty': 1,
#   'from': 1,
#   'her': 1,
#   'mortal': 1,
#   'day': 1},
#  'line 1286': {'Down': 1,
#   'by': 1,
#   'the': 1,
#   'river': 1,
#   'of': 1,
#   'Adona': 1,
#   'her': 1,
#   'soft': 1,
#   'voice': 1,
#   'is': 1,
#   'heard': 1},
#  'line 1287': {'And': 1,
#   'thus': 1,
#   'her': 1,
#   'gentle': 1,
#   'lamentation': 1,
#   'falls': 1,
#   'like': 1,
#   'morning': 1,
#   'dew': 1},
#  'line 1289': {'O': 1,
#   'life': 1,
#   'of': 2,
#   'this': 1,
#   'our': 1,
#   'spring': 1,
#   'why': 1,
#   'fades': 1,
#   'the': 2,
#   'lotus': 1,
#   'water': 1},
#  'line 1290': {'Why': 1,
#   'fade': 1,
#   'these': 1,
#   'children': 1,
#   'of': 1,
#   'the': 1,
#   'spring': 1,
#   'born': 1,
#   'but': 1,
#   'to': 1,
#   'smile': 1,
#   'fall': 1},
#  'line 1291': {'Ah': 1,
#   'Thel': 1,
#   'is': 1,
#   'like': 2,
#   'a': 2,
#   'watry': 1,
#   'bow': 1,
#   'and': 1,
#   'parting': 1,
#   'cloud': 1},
#  'line 1292': {'Like': 1,
#   'a': 2,
#   'reflection': 1,
#   'in': 2,
#   'glass': 1,
#   'like': 1,
#   'shadows': 1,
#   'the': 1,
#   'water': 1},
#  'line 1293': {'Like': 1,
#   'dreams': 1,
#   'of': 1,
#   'infants': 2,
#   'like': 1,
#   'a': 1,
#   'smile': 1,
#   'upon': 1,
#   'an': 1,
#   'face': 1},
#  'line 1294': {'Like': 1,
#   'the': 2,
#   'doves': 1,
#   'voice': 1,
#   'like': 2,
#   'transient': 1,
#   'day': 1,
#   'music': 1,
#   'in': 1,
#   'air': 1},
#  'line 1295': {'Ah': 1,
#   'gentle': 2,
#   'may': 1,
#   'I': 1,
#   'lay': 1,
#   'me': 1,
#   'down': 1,
#   'and': 1,
#   'rest': 1,
#   'my': 1,
#   'head': 1},
#  'line 1296': {'And': 1,
#   'gentle': 1,
#   'sleep': 2,
#   'the': 2,
#   'of': 1,
#   'death': 1,
#   'and': 1,
#   'gently': 1,
#   'hear': 1,
#   'voice': 1},
#  'line 1297': {'Of': 1,
#   'him': 1,
#   'that': 1,
#   'walketh': 1,
#   'in': 2,
#   'the': 2,
#   'garden': 1,
#   'evening': 1,
#   'time': 1},
#  'line 1299': {'The': 1,
#   'Lilly': 1,
#   'of': 1,
#   'the': 2,
#   'valley': 1,
#   'breathing': 1,
#   'in': 1,
#   'humble': 1,
#   'grass': 1},
#  'line 1300': {'Answerd': 1,
#   'the': 1,
#   'lovely': 1,
#   'maid': 1,
#   'and': 1,
#   'said': 1,
#   'I': 1,
#   'am': 1,
#   'a': 1,
#   'watry': 1,
#   'weed': 1},
#  'line 1301': {'And': 1,
#   'I': 1,
#   'am': 1,
#   'very': 1,
#   'small': 1,
#   'and': 1,
#   'love': 1,
#   'to': 1,
#   'dwell': 1,
#   'in': 1,
#   'lowly': 1,
#   'vales': 1},
#  'line 1302': {'So': 1,
#   'weak': 1,
#   'the': 1,
#   'gilded': 1,
#   'butterfly': 1,
#   'scarce': 1,
#   'perches': 1,
#   'on': 1,
#   'my': 1,
#   'head': 1},
#  'line 1303': {'Yet': 1,
#   'I': 1,
#   'am': 1,
#   'visited': 1,
#   'from': 1,
#   'heaven': 1,
#   'and': 1,
#   'he': 1,
#   'that': 1,
#   'smiles': 1,
#   'on': 1,
#   'all': 1},
#  'line 1304': {'Walks': 1,
#   'in': 1,
#   'the': 1,
#   'valley': 1,
#   'and': 1,
#   'each': 1,
#   'morn': 1,
#   'over': 1,
#   'me': 1,
#   'spreads': 1,
#   'his': 1,
#   'hand': 1},
#  'line 1305': {'Saying': 1,
#   'rejoice': 1,
#   'thou': 2,
#   'humble': 1,
#   'grass': 1,
#   'new': 1,
#   'born': 1,
#   'lily': 1,
#   'flower': 1},
#  'line 1306': {'Thou': 1,
#   'gentle': 1,
#   'maid': 1,
#   'of': 2,
#   'silent': 1,
#   'valleys': 1,
#   'and': 1,
#   'modest': 1,
#   'brooks': 1},
#  'line 1307': {'For': 1,
#   'thou': 1,
#   'shall': 1,
#   'be': 1,
#   'clothed': 1,
#   'in': 1,
#   'light': 1,
#   'and': 1,
#   'fed': 1,
#   'with': 1,
#   'morning': 1,
#   'manna': 1},
#  'line 1308': {'Till': 1,
#   'summers': 1,
#   'heat': 1,
#   'melts': 1,
#   'thee': 1,
#   'beside': 1,
#   'the': 2,
#   'fountains': 1,
#   'and': 1,
#   'springs': 1},
#  'line 1309': {'To': 1,
#   'flourish': 1,
#   'in': 1,
#   'eternal': 1,
#   'vales': 1,
#   'they': 1,
#   'why': 1,
#   'should': 1,
#   'Thel': 1,
#   'complain': 1},
#  'line 1310': {'Why': 1,
#   'should': 1,
#   'the': 2,
#   'mistress': 1,
#   'of': 2,
#   'vales': 1,
#   'Har': 1,
#   'utter': 1,
#   'a': 1,
#   'sigh': 1},
#  'line 1312': {'She': 1,
#   'ceasd': 1,
#   'smild': 1,
#   'in': 2,
#   'tears': 1,
#   'then': 1,
#   'sat': 1,
#   'down': 1,
#   'her': 1,
#   'silver': 1,
#   'shrine': 1},
#  'line 1314': {'Thel': 1,
#   'answerd': 1,
#   'O': 1,
#   'thou': 1,
#   'little': 1,
#   'virgin': 1,
#   'of': 1,
#   'the': 1,
#   'peaceful': 1,
#   'valley': 1},
#  'line 1315': {'Giving': 1,
#   'to': 1,
#   'those': 1,
#   'that': 1,
#   'cannot': 1,
#   'crave': 1,
#   'the': 2,
#   'voiceless': 1,
#   'o': 1,
#   'er': 1,
#   'tired': 1},
#  'line 1316': {'The': 1,
#   'breath': 1,
#   'doth': 1,
#   'nourish': 1,
#   'the': 2,
#   'innocent': 1,
#   'lamb': 1,
#   'he': 1,
#   'smells': 1,
#   'milky': 1,
#   'garments': 1},
#  'line 1317': {'He': 1,
#   'crops': 1,
#   'thy': 1,
#   'flowers': 1,
#   'while': 1,
#   'thou': 1,
#   'sittest': 1,
#   'smiling': 1,
#   'in': 1,
#   'his': 1,
#   'face': 1},
#  'line 1318': {'Wiping': 1,
#   'his': 1,
#   'mild': 1,
#   'and': 1,
#   'meekin': 1,
#   'mouth': 1,
#   'from': 1,
#   'all': 1,
#   'contagious': 1,
#   'taints': 1},
#  'line 1319': {'Thy': 1,
#   'wine': 1,
#   'doth': 1,
#   'purify': 1,
#   'the': 1,
#   'golden': 1,
#   'honey': 1,
#   'thy': 1,
#   'perfume': 1},
#  'line 1320': {'Which': 1,
#   'thou': 1,
#   'dost': 1,
#   'scatter': 1,
#   'on': 1,
#   'every': 1,
#   'little': 1,
#   'blade': 1,
#   'of': 1,
#   'grass': 1,
#   'that': 1,
#   'springs': 1},
#  'line 1321': {'Revives': 1,
#   'the': 2,
#   'milked': 1,
#   'cow': 1,
#   'tames': 1,
#   'fire': 1,
#   'breathing': 1,
#   'steed': 1},
#  'line 1322': {'But': 1,
#   'Thel': 1,
#   'is': 1,
#   'like': 1,
#   'a': 1,
#   'faint': 1,
#   'cloud': 1,
#   'kindled': 1,
#   'at': 1,
#   'the': 1,
#   'rising': 1,
#   'sun': 1},
#  'line 1323': {'I': 1,
#   'vanish': 1,
#   'from': 1,
#   'my': 2,
#   'pearly': 1,
#   'throne': 1,
#   'and': 1,
#   'who': 1,
#   'shall': 1,
#   'find': 1,
#   'place': 1},
#  'line 1325': {'Queen': 1,
#   'of': 1,
#   'the': 3,
#   'vales': 1,
#   'Lily': 1,
#   'answered': 1,
#   'ask': 1,
#   'tender': 1,
#   'cloud': 1},
#  'line 1326': {'And': 1,
#   'it': 2,
#   'shall': 1,
#   'tell': 1,
#   'thee': 1,
#   'why': 1,
#   'glitters': 1,
#   'in': 1,
#   'the': 1,
#   'morning': 1,
#   'sky': 1},
#  'line 1327': {'And': 1,
#   'why': 1,
#   'it': 1,
#   'scatters': 1,
#   'its': 1,
#   'bright': 1,
#   'beauty': 1,
#   'thro': 1,
#   'the': 1,
#   'humid': 1,
#   'air': 1},
#  'line 1328': {'Descend': 1,
#   'O': 1,
#   'little': 1,
#   'cloud': 1,
#   'hover': 1,
#   'before': 1,
#   'the': 1,
#   'eyes': 1,
#   'of': 1,
#   'Thel': 1},
#  'line 1330': {'The': 1,
#   'Cloud': 1,
#   'descended': 1,
#   'and': 1,
#   'the': 1,
#   'Lily': 1,
#   'bowd': 1,
#   'her': 1,
#   'modest': 1,
#   'head': 1},
#  'line 1331': {'And': 1,
#   'went': 1,
#   'to': 1,
#   'mind': 1,
#   'her': 1,
#   'numerous': 1,
#   'charge': 1,
#   'among': 1,
#   'the': 1,
#   'verdant': 1,
#   'grass': 1},
#  'line 1334': {'II': 1},
#  'line 1336': {'O': 1,
#   'little': 1,
#   'Cloud': 1,
#   'the': 1,
#   'virgin': 1,
#   'said': 1,
#   'I': 1,
#   'charge': 1,
#   'thee': 1,
#   'to': 1,
#   'tell': 1,
#   'me': 1},
#  'line 1337': {'Why': 1,
#   'thou': 2,
#   'complainest': 1,
#   'now': 1,
#   'when': 1,
#   'in': 1,
#   'one': 1,
#   'hour': 1,
#   'fade': 1,
#   'away': 1},
#  'line 1338': {'Then': 1,
#   'we': 1,
#   'shall': 1,
#   'seek': 1,
#   'thee': 2,
#   'but': 1,
#   'not': 1,
#   'find': 1,
#   'ah': 1,
#   'Thel': 1,
#   'is': 1,
#   'like': 1,
#   'to': 1},
#  ...}
